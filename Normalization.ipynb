# %%
import re
dict_words = {}
count = 0
with open('data/dictionary.txt') as f:
    for word in f.readlines():
        word = word.replace('\n', '')
        word = word.lower()
        if 'ngc' == word:
            continue
        if 'ic' == word:
            continue
        if 'ugc' == word:
            continue
        if 'eso' == word:
            continue
        if 'mcg' == word:
            continue
        if 'pk' == word:
            continue
        dict_words[word] = True

# %%
SEP = '|' # This is the new delimiter character
headers = []
entries = []
objs = []

with open('db.dat') as f:
    lines = f.readlines()

    for header in lines[0].split(SEP):
        headers.append(header)

    for idx in range(1, len(lines[1:])):
        line = lines[idx]
        paths = line.split(SEP)
        obj = {}
        for col in range(0, len(paths) - 1):
            obj[headers[col]] = paths[col]
        objs.append(obj)

# %% [markdown]
# ## Constellations

# %%
constellations = {}
constellations_4letter = {}
constellations_3letter = {}

with open('data/constellations.txt') as f:
    lines = f.readlines()
    for line in lines:
        cols = line.split('\t')
        name = cols[1]
        l3 = cols[3].lower()
        l4 = cols[4].lower()
        constellations[l4] = name
        constellations[l3] = name
        constellations_4letter[l4] = name
        constellations_3letter[l3] = name
        constellations[name] = name
        constellations[name.lower()] = name

def extract_constellation(txt):
    for constellation in constellations:
        if constellation in txt:
            return constellations[constellation]
    return ''
        
def normalize_constellations(txt):
    txt = re.sub(r'[^a-zA-Z\s\d]', '', txt)
    good_word_count = 0
    for word in txt.split(' '):
        if word.lower() in dict_words:
            good_word_count = good_word_count + 1
        
    words = {}
    result = []
    for word in txt.split(' '):
        # Do not duplicate words
        candidate = word
            
        # Special case for the common word "and"
        if word.lower() == "and" and good_word_count > 1:
            result.append(word)
            continue
        
        if word.lower() in constellations_4letter:
            candidate = constellations_4letter[word.lower()]
        elif word.lower() in constellations_3letter:
            candidate = constellations_3letter[word.lower()]
        elif word.lower() in constellations:
            candidate = constellations[word.lower()]
            
        
        if candidate in words:
            continue
        
        result.append(candidate)
        
        for w in candidate.split(' '):
            words[w] = w

    final_word = ' '.join(result).strip()    
    return final_word

# %% [markdown]
# ## Duplicate grouping

# %%
groups = {}
for obj in objs:
    if obj['dup_id'] not in groups:
        groups[obj['dup_id']] = []
    groups[obj['dup_id']].append(obj)

# %% [markdown]
# ## Normalize Designations

# %%
def normalize_designation(designation):
    if 'star' in designation.lower():
        return 'Star'
    
    if 'ass' in designation.lower():
        return 'Asterism'
    
    lookup = {
        'ASTER': 'Asterism',
        'BRTNB': 'Bright Nebula',
        'CL+NB': 'Cluster',
        'DRKNB': 'Dark Nebula',
        'GALCL': 'Galaxy Cluster',
        'GALXY': 'Galaxy',
        'GLOCL': 'Globular Cluster',
        'GX+DN': 'Nebula',
        'GX+GC': 'Globular Cluster',
        'G+C+N': 'Cluster',
        'LMCCN': 'Cluster',
        'LMCDN': 'Nebula',
        'LMCGC': 'Globular Cluster',
        'LMCOC': 'Open Cluster',
        'OPNCL': 'Open Cluster',
        'NONEX': '',
        'PLNNB': 'Nebula',
        'SMCCN': 'Cluster',
        'SMCDN': 'Nebula',
        'SMCGC': 'Globular Cluster',
        'SMCOC': 'Open Cluster',
        'SNREM': 'Supernova Remnant',
        'QUASR': 'Quasar',
        'G': 'Galaxy',
        'GGroup': 'Galaxy',
        'GPair': 'Galaxy',
        'Gtrpl': 'Galaxy',
        'OCl': 'Open Cluster',
        'GCl': 'Globular Cluster',
        'Cl+N': 'Cluster',
        'PN': 'Nebula',
        'HII': 'Nebula',
        'Neb': 'Nebula',
        'EmN': 'Nebula',
        'RfN': 'Nebula',
        'SNR': 'Supernova Remnant,'
        ''
    }
    
    if designation in lookup:
        return lookup[designation]
    
    return designation

# %% [markdown]
# ## Name
# This will take a comma-separated list of names and extract the best name

# %%
def count_upper_case(name):
    count = 0
    for c in name:
        if c.isupper():
            count += 1
    return count

def get_name_score(name):
    score = 0.0
    if len(name) == 0:
        return -100

    name = name.strip()

    words = {}
    for word in name.split(' '):
        # Penalize the same word repeated
        if word in words:
            score -= 0.25
        if word.lower() in dict_words:
            score += 0.51
        if word.lower() in constellations:
            score += 0.05
        if 'ngc' in word.lower():
            score += 0.05
        if '+' in word:
            score -= 0.05
        if '-' in word:
            score -= 0.05
            
        # Inherently penalize more words
        score -= 0.025
        
        words[word] = word
        # score += count_upper_case(word) * 0.02
    return score

def get_best_name(item_names):
    name_list = item_names.split(',')
    best_name = name_list[0]
    best_score = -100.0
    
    for name in name_list:
        name_score = get_name_score(name)
        if name_score > best_score:
            best_name = name.replace("\'", '')
            best_score = name_score
    
    best_name_words = []
    is_m = False
    
    for word in best_name.split(' '):
        if word == 'M':
            is_m = True
        
        if 'mcg' in word.lower():
            best_name_words.append(word.upper())
        elif word.lower() in dict_words:
            best_name_words.append(word.capitalize())
        else:
            best_name_words.append(word)
            
    if is_m:
        return ''.join(best_name_words)
    else:
        return ' '.join(best_name_words)

# %% [markdown]
# ## Polyfill blanks

# %%
polyfill_attrs = ['mag', 'names', 'designation', 'ngc_id', 'surface_brightness', 'M', 'NGC', 'IC', 'constellation', 'classifiers', 'descriptors', 'notes', 'remnant_type', 'HD_ID', 'SAO_ID', 'FK5_ID', 'bv_mag', 'ub_mag', 'b_mag', 'v_mag', 'j_mag']
UNKNOWN_MAGNITUDE = '99.0'

def normalize_str(name):
    name = normalize_constellations(name)
    name = name.replace('   ', ' ')
    name = name.replace('  ', ' ')
    name = name.strip()
    return name

def polyfill(items):
    names = []
    for item in items:
        item_names_str = item['names']
        item_names_str = re.sub(r';', ',', item_names_str)
        full_name_candidate  = item_names_str.split(',')
        full_name_candidate.extend(item['FK5_ID'].split(','))
        name_list = ','.join(full_name_candidate).split(',')
        for idx in range(0, len(name_list)):
            name_list[idx] = normalize_str(name_list[idx])
        
        names.extend(name_list)
    
    # If this is an IAU star, just automatically make the name win
    for item in items:
        if item['catalog'] == 'IAU Star Database':
            names = [normalize_str(item['names'])]
    
    names = set(names)
    for attr in polyfill_attrs:
        non_empty_value = ''
        smallest = float('infinity')
        largest = -float('infinity')
        for item in items:
            if attr not in item:
                item[attr] = ''
                
            # Clean up some stuff
            if attr == 'constellation':
                item[attr] = normalize_constellations(item[attr])
            if attr == 'designation':
                item[attr] = normalize_designation(item[attr])

            if attr == 'names':
                item[attr] = ','.join(names)
            
            # Remove things that are known to be bad
            if attr == 'designation' and item[attr] == 'Dup':
                item[attr] = ''
            
            # If the magnitude is clearly wrong, reset it to the unknown value
            # (Note: some databases define a blank magnitude as either 74 or 99)
            # So the sweeping threshold of "greather than 70 is bad" seems reasonable
            try:
                if attr == 'mag' and float(item[attr]) >= 70.0:
                    item[attr] = UNKNOWN_MAGNITUDE
            except:
                item[attr] = UNKNOWN_MAGNITUDE
                pass
            
            v = str(item[attr]).strip()
            if len(v) > 0:
                non_empty_value = item[attr]
                try:
                    vnum = float(non_empty_value)
                    if smallest > vnum:
                        smallest = vnum
                    if largest < vnum:
                        largest = vnum
                except:
                    pass
        
        for item in items:    
            v = str(item[attr]).strip()
            if attr in ['surface_brightness', 'mag', 'b_mag', 'v_mag', 'j_mag', 'bv_mag', 'ub_mag'] and smallest != float('infinity'):
                item[attr] = smallest
            elif len(v) == 0:
                item[attr] = non_empty_value

        for item in items:
            # extract constallation from name, if missing
            if len(item['constellation'].strip()) == 0:
                item['constellation'] = extract_constellation(item['names'])
    
    final_name = get_best_name(items[0]['names'])
    for item in items:
        item['best_name'] = final_name

# %%
for groupId in groups:
    polyfill(groups[groupId])

# %%
# csv = 'SEP=|\nbest_name|'
csv = 'best_name|' + '|'.join(headers) # no need for trailing \n because it's in the header list for some reason

for groupId in groups:
    candidate = groups[groupId][0]
    
    # Always choose IAU Star Database
    for item in groups[groupId]:
        if item['catalog'] == 'IAU Star Database':
            candidate = item
    
    if len(candidate['best_name']) == 0:
        continue
    csv += candidate['best_name'] + '|'
    for header in headers:
        if '\n' in header:
            continue
        if header in candidate:
            csv += str(candidate[header])
        csv += '|'
    csv += '\n'
    

with open('stardb.pipe', '+w') as f:
    f.write(csv)

# %%
results = []

for groupId in groups:
    for candidate in groups[groupId]:
        done = False
        for word in candidate['best_name'].split(' '):
            if word.lower() in dict_words:
                if 'NGC' not in word:
                    results.append(candidate['best_name'])
                    done = True
                    break
        if done:
            break

print(f"Found {len(results)} results")
print("")
for word in results:
    print(word)
# Out:
# Found 4388 results
#
# H Iii 207
# omi Perseus Cloud
# Barnards Merope Nebula
# Flaming Star Nebula
# Orion B
# Gemini A
# Sadr
# H I 100
# The Witch Head Nebula
# Toby Jug Nebula
# omi Vela Cluster
# Browning
# H Iii 596
# Coddingtons Nebula
# Tet Carina Cluster
# Lam Centaurus Nebula
# Rho Ophiuchus Nebula
# 22 Scorpius
# H Iv 57
# Star Queen
# Small Sagittarius Star Cloud
# Barnards Galaxy
# Pelican Nebula
# Cocoon Nebula
# Bowtie Nebula
# 47 Tucana Cluster
# Andromeda Galaxy
# Sculptor Filament
# Small Magellanic Cloud
# Owl Cluster
# Triangulum Galaxy
# Little Dumbbell Nebula
# H Persei Cluster
# Chi Persei Cluster
# MCG 2 7 54
# Fornax Dwarf Cluster 3
# Perseus A
# Fornax A
# Fornax B
# Maia
# Merope Nebula
# California Nebula
# Hinds Variable Nebula
# Crab Nebula
# Great Orion Nebula
# The Running Man Nebula
# Lower Sword
# Upper Sword
# Mairans Nebula
# 46Eps Orion
# 30 Dorado Cluster
# 3 Monoceros
# Monkey Head Nebula
# Rosette A
# Rosette Nebula
# Rosette B
# Hubbles Nebula
# Christmas Tree Cluster
# Great Bird Cluster
# Carolines Cluster
# 30Tau Canis Major
# Eskimo Nebula
# Bear Claw Nebula
# 19 Puppis
# Polarissima Australis
# Praesepe Cluster
# Helix Galaxy
# Pencil Nebula
# Bodes Galaxy
# Cigar Galaxy
# Spindle Galaxy
# EightBurst Nebula
# Polarissima Borealis
# Jupiters Ghost Nebula
# Eta Carina Nebula
# Wishing Well Cluster
# The Guitar
# Owl Nebula
# Pearl Cluster
# Blue Planetary
# Miniature Spiral
# Antennae Galaxies
# Antennae Galaxies
# Medusa Galaxy Merger
# Virgo Cluster Pinwheel
# Eyes
# Eyes
# Virgo Galaxy
# Needle Galaxy
# Butterfly Galaxies
# Butterfly Galaxies
# Sombrero Galaxy
# Coalsack Cluster
# Whale Galaxy
# Umbrella Galaxy
# Mice Galaxy
# Kappa Crucis Cluster
# Black Eye Galaxy
# Cocoon Galaxy
# Sunflower Galaxy
# Centaurus A
# Omega Centauri
# Whirlpool Galaxy
# Southern Pinwheel Galaxy
# S Norma Cluster
# Rim Nebula
# Hercules Globular Cluster
# Bug Nebula
# Box Nebula
# The War And Peace Nebula
# Little Ghost Nebula
# Butterfly Cluster
# Little Gemini
# Ptolemys Cluster
# Trifid Nebula
# Lagoon Nebula
# Red Spider Nebula
# Cats Eye Nebula
# Eagle Nebula
# Omega Nebula
# Wild Duck Cluster
# Ring Nebula
# Phantom Streak Nebula
# Little Gemini Nebula
# Foxhead Cluster
# MCG 150 2
# Blinking Planetary
# Dumbbell Nebula
# Crescent Nebula
# Blue Flash Nebula
# Fireworks Galaxy
# Western Veil
# Eastern Veil
# Eastern Veil
# North America Nebula
# Saturn Nebula
# Iris Nebula
# Schmidts Nova Cygni
# Helix Nebula
# MCG 159 2
# Bubble Nebula
# Copelands Blue Snowball
# V 166
# V 166
# V 166
# MCG 4 2 3
# MCG 4 2 9
# MCG 4 2 14
# And Iii
# Arp 282
# MCG 5 2 32
# MCG 4 2 49
# And I
# MCG 5 2 43
# Abell 262
# Mrk 2
# Abell 347
# ESO 374 2
# ESO 376 2
# Gcl 30
# Gcl 40
# Abell 48
# Berk 79
# Berk 80
# Ap 21
# Sao 142915
# B 127
# Berk 81
# B 129
# B 132
# Abell 52
# Gcl 107
# B 133
# Abell 53
# B 134
# B 135
# Abell 55
# Gcl 109
# Berk 82
# Abell 56
# Berk 43
# B 137
# B 138
# B 139
# Abell 58
# Nassau 2
# Berk 45
# King 25
# Do 35
# King 26
# Abell 62
# B 336
# B 334
# B 335
# B 337
# Cr 401
# Merrill 11
# B 142
# B 143
# Ap 22
# Pal 11
# Abell 67
# Abell 70
# Aquarius Dwarf
# Abell 76
# MCG 356 2
# Am 2148554
# MCG 357 2
# MCG 158 2
# Gcl 125
# MCG 360 2
# ESO 606 2
# Ced 211
# Ru 120
# Cr 307
# Ru 121
# Hogg 20
# Hogg 21
# Hogg 22
# Harvard 13
# Dunlop 417
# Cannon 14
# Dunlop 225
# Lacerta III11
# Shapley 3
# MCG 2 6 52
# MCG 2 7 23
# MCG 2 8 16
# B 202
# B 203
# B 204
# B 206
# Crl 618
# Pal 2
# B 25
# B 26
# Berk 14
# Berk 15
# Do 15
# B 29
# Abell 8
# K2 1
# King 17
# Do 16
# Mel 31
# Cr 61
# Berk 17
# King 22
# Cr 62
# Berk 19
# Do 18
# Berk 69
# Berk 70
# Stock 8
# Do 20
# Stock 10
# Berk 71
# B 34
# Basel 4
# King 8
# Gcl 27
# Stock 23
# King 6
# Berk 10
# Tombaugh 5
# Kemble 1
# M2 2
# B 9
# B 8
# Mayer 2
# B 11
# B 12
# B 13
# B 21
# Berk 13
# Cr 464
# MCG 252 2
# Pal 12
# MCG 255 2
# ESO 165 2
# ESO 61 2
# Gcl 13
# Ru 159
# Ru 84
# Ru 86
# Cr 216
# Hogg 5
# Hogg 6
# Cr 217
# Ru 161
# Ru 88
# Tr 13
# Cr 222
# Cr 223
# Ru 90
# Bochum 9
# Mel 101
# Bochum 10
# Cr 229
# Tr 14
# Cr 228
# Cr 231
# Cr 232
# Dunlop 309
# Tr 16
# Cr 234
# Gum 32
# Bochum 11
# Ru 91
# Ru 162
# Ru 92
# Cr 235
# Graham 1
# Cr 236
# Bochum 12
# Hogg 9
# Sher 1
# Ru 93
# Ru 163
# Fein 1
# Hogg 10
# Tr 18
# Hogg 11
# Cr 240
# Hogg 12
# Stock 13
# Cr 243
# Hogg 13
# Cr 245
# Mel 105
# Berk 58
# Stock 18
# Berk 104
# Stock 19
# Berk 1
# King 13
# Berk 60
# Bv 51
# King 1
# Mayer 1
# Berk 2
# Stock 20
# Hu 11
# Stock 21
# King 14
# King 15
# Stock 24
# Do 12
# Czernik 2
# King 16
# Berk 4
# Abell 2
# Berk 61
# Do 13
# King 2
# Berk 62
# Stock 3
# Cr 15
# Cr 463
# Berk 5
# Berk 6
# Bv 3
# Berk 7
# Berk 8
# 50 Cassiopeia
# Stock 5
# Abell 3
# Stock 2
# Berk 63
# Berk 64
# Stock 6
# Sg 1 4
# Tombaugh 4
# Cr 26
# Mel 15
# King 4
# Maffei 1
# Berk 65
# Abell 6
# Cr 33
# Cr 34
# Berk 66
# Tr 3
# Do 46
# Hubble 12
# Stock 11
# King 20
# Stock 12
# Berk 102
# Stock 17
# Berk 103
# Abell 82
# Abell 83
# Abell 84
# King 21
# King 12
# Harvard 21
# Fleming 1
# Gum 39
# Gum 41
# Ru 94
# Pb 8
# Cr 249
# Ru 95
# Stock 14
# Mel 108
# Ru 96
# Ru 106
# Dunlop 311
# Dunlop 411
# Danks 2
# Stock 16
# ESO 220 2
# ESO 270 2
# Loden 807
# Ced 122
# Dunlop 482
# Omega Centauri
# Basel 18
# Hogg 16
# Cr 271
# Cr 272
# Ru 108
# Cr 274
# Cr 275
# Dunlop 388
# Be 146
# Ru 167
# Lynga 2
# Tr 22
# Hogg 17
# Ru 111
# Abell 86
# Berk 59
# Ced 214
# Abell 1
# Pal 1
# B 148
# B 150
# Abell 73
# Cr 427
# B 152
# Ced 191
# Berk 92
# Abell 75
# Abell 77
# B 365
# Ced 194
# B 160
# Cr 439
# B 161
# B 162
# B 163
# B 367
# Berk 93
# B 170
# B 169
# B 171
# Cr 471
# B 174
# B 173
# Cr 447
# Berk 94
# Berk 95
# Berk 97
# King 18
# King 10
# Berk 57
# Ced 208
# King 19
# Berk 99
# Berk 100
# Berk 101
# King 11
# Wlm
# MCG 2 1 13
# MCG 2 1 24
# MCG 2 1 33
# MCG 2 1 43
# MCG 2 11
# MCG 2 14
# MCG 1 2 16
# MCG 1 2 17
# MCG 0 2 29
# Arp 19
# MCG 2 53
# MCG 2 55
# MCG 2 56
# MCG 2 63
# MCG 2 66
# MCG 2 69
# MCG 0 2 91
# MCG 2 77
# MCG 3 2 34
# MCG 2 79
# MCG 3 2 35
# MCG 2 81
# MCG 2 85
# MCG 2 3 17
# MCG 2 3 21
# MCG 2 3 27
# Arp 140
# MCG 2 3 28
# MCG 2 3 31
# MCG 2 3 33
# Kaz 377
# MCG 2 3 34
# MCG 2 3 35
# MCG 2 3 50
# ESO 541 2
# MCG 2 3 64
# New 1
# MCG 2 4 30
# Arp 8
# MCG 2 4 53
# MCG 2 5 3
# MCG 2 5 4
# MCG 2 5
# MCG 2 5 7
# MCG 2 5 10
# MCG 4 5 2
# MCG 2 5 31
# MCG 2 5 33
# MCG 2 5 34
# MCG 2 5 37
# ESO 477 2
# MCG 2 5 52
# MCG 2 5 59
# MCG 2 5 60
# MCG 2 5 63
# MCG 2 5 68
# MCG 2 5 69
# MCG 2 5 75
# MCG 2 6 3
# MCG 2 6 7
# MCG 2 6 10
# MCG 2 6 11
# MCG 2 6 15
# MCG 2 6 21
# MCG 2 6 23
# MCG 2 6 24
# MCG 2 6 30
# MCG 2 6 31
# MCG 2 6 33
# MCG 2 6 34
# MCG 2 6 36
# MCG 2 6 38
# MCG 2 6 48
# MCG 1 7 2
# MCG 2 7 9
# MCG 2 7 13
# MCG 2 7 15
# MCG 2 7 18
# MCG 2 7 21
# MCG 2 7 28
# MCG 2 7 30
# MCG 2 7 31
# MCG 2 7 35
# MCG 2 7 37
# MCG 2 7 45
# MCG 2 7 46
# MCG 2 7 47
# MCG 2 7 48
# MCG 2 7 53
# MCG 2 7 59
# MCG 2 7 58
# MCG 2 7 71
# MCG 2 7 77
# MCG 3 8 2
# MCG 2 8 1
# NGC 1080
# Abell 400
# Be 142
# Sa 156
# Ru 110
# Circinus Dwarf
# Be 145
# Ru 112
# Sa 172
# Abell 15
# Ru 1
# Ru 2
# Berk 25
# Ru 3
# ESO 427 2
# Berk 75
# Ru 5
# Ru 6
# Cr 121
# Ru 7
# Tombaugh 1
# Ru 8
# Pb 1
# Tombaugh 2
# Ced 89B
# Ced 90
# Ru 150
# Ru 10
# K2 3
# Ru 12
# Ru 11
# Ru 13
# Gum 5
# M3 2
# Ru 14
# Cr 132
# Berk 36
# Basel 11A
# Ru 15
# Ced 96
# VY Canis Major
# Ru 16
# Ru 17
# Cr 140
# Ru 18
# Ru 19
# Cr 145
# Ru 20
# Berk 35
# King 23
# Abell 20
# Berk 78
# Do 26
# Abell 22
# Abell 24
# Abell 30
# Abell 31
# Dunlop 508
# Arp 305a
# Ho 348b
# Mel 111
# Ho 400a
# Ho 426
# Ho 423c
# Ho 468b
# Ho 469
# Ho 490b
# Ii Zw 67
# Coma Berenices I
# Ho 499b
# Gcl 23
# V 133
# Dunlop 473
# Be 157
# Sl 42
# Abell 2065
# Abell 2162
# MCG 230 2
# Ru 97
# Ru 98
# Ru 99
# Ru 101
# Stock 15
# Ru 102
# Ru 104
# Harvard 5
# Hogg 23
# Ru 165
# Hogg 14
# Tr 20
# Hogg 15
# Coalsack
# H I 136
# Holmberg Viii
# Arp 111
# Abell 61
# Pc 23
# B 144
# Berk 49
# Do 36
# B 145
# Ced 174
# B 146
# Berk 84
# Basel 6
# Biur 2
# Do 2
# Berk 50
# Ru 172
# Berk 51
# B 343
# Do 3
# Do 39
# H Iv 13
# Cr 418
# Do 4
# Cr 419
# Do 40
# Berk 85
# Do 41
# Do 42
# Abell 69
# Berk 86
# Do 6
# Do 5
# Berk 88
# Berk 87
# Do 43
# Cr 421
# Do 8
# Berk 89
# Do 9
# Do 11
# B 346
# B 347
# Do 44
# Abell 71
# Berk 90
# B 348
# Do 47
# Ru 173
# Ru 174
# Ru 175
# B 350
# Sg 3202
# Bark 1
# Berk 53
# Ced 182B
# B 352
# Ced 182C
# Le Gentil 3
# Crl 2688
# Berk 54
# Cr 428
# Do 45
# Basel 12
# Berk 91
# Cr 432
# B 361
# Basel 13
# Basel 15
# Berk 55
# Berk 56
# Basel 14
# B 362
# Hu 12
# B 364
# B 157
# Abell 78
# Bark 2
# B 164
# B 168
# H Iv 16
# Gcl 117
# Abell 72
# Gcl 119
# Dunlop 114
# Lg Magellanic Cl
# MCG 1210 2
# Ho 337b
# Keeler 690
# Draco Dwarf
# Kemble 2
# MCG 835 2
# MCG 2 8 5
# MCG 2 8 11
# MCG 2 8 15
# MCG 2 8 19
# MCG 2 8 34
# MCG 2 8 35
# MCG 2 8 36
# MCG 2 8 41
# MCG 2 8 42A
# MCG 2 8 42B
# MCG 2 8 43
# MCG 2 8 45
# MCG 2 8 47
# MCG 2 8 51
# MCG 2 8 55
# MCG 2 8 56
# MCG 1 9 2
# MCG 2 9 10
# MCG 2 9 11
# MCG 2 9 12
# MCG 2 9 14
# MCG 2 9 22
# MCG 2 9 25
# MCG 2 9 30
# MCG 2 9 42
# MCG 2 9 44
# MCG 110 2
# Fcc 202
# Eridanus Cluster
# Ho 77a
# MCG 113 2
# MCG 114 2
# Fornax Dwarf
# ESO 358 2
# Cr 80
# Cr 89
# Bochum 1
# J 900
# Berk 23
# Berk 29
# Abell 19
# Abell 21
# Abell 2147
# Hercules Galxy Cl
# Abell 2152
# Pal 14
# Abell 39
# Abell 2197
# Abell 2199
# Arp 125
# Gcl 47
# Arp 103
# Hu 21
# ESO 115 2
# Gcl 5
# MCG 223 2
# MCG 224 2
# Hydra A
# MCG 325 2
# Abell 33
# Abell 34
# Hydra I
# ESO 502 2
# Abell 35
# Abell 1736
# Gcl 29
# ESO 80 2
# ESO 237 2
# Cr 445
# King 9
# Abell 79
# Berk 96
# Merrill 22
# Abell 80
# Berk 98
# Leo Iii
# Leo I
# MCG 128 2
# Leo Ii
# Abell 1367
# Abell 7
# ESO 487 2
# Abell 548
# MCG 337 2
# MCG 239 2
# Gcl 33
# ESO 514 2
# MCG 139 2
# Merrill 21
# MCG 340 2
# MCG 240 2
# Arp 267
# ZwG 155 2
# Hogg 18
# Gcl 35
# B 228
# Dunlop 552
# Sl 11
# Sl 7
# Abell 16
# Abell 569
# Abell 576
# Gcl 12
# Abell 779
# Abell 46
# K2 6
# ESO 16 2
# Cr 91
# Berk 73
# Cr 92
# Cr 96
# Cr 95
# Cr 97
# B 37
# B 38
# Basel 8
# Basel 7
# Cr 104
# Cr 105
# Cr 106
# Cr 107
# Berk 24
# B 39
# Cr 110
# Cr 111
# Do 23
# Do 24
# Do 25
# Cr 115
# Abell 17
# Bochum 2
# Ru 4
# Berk 26
# Berk 28
# K2 2
# Abell 18
# Berk 32
# Bochum 3
# Gum 1
# Gum 2
# Berk 76
# Cr 465
# Cr 466
# Ced 92
# Berk 37
# Berk 77
# Mel 72
# Berk 39
# Abell 25
# Do 22
# Dark Doodad
# Gcl 19
# Cr 261
# Lacerta I4
# Cr 268
# Ru 107
# Cr 269
# Cr 277
# Harvard 9
# Cr 292
# Cannon 11
# Shapley 1
# Ru 113
# Cr 295
# Moffat 1
# Ru 114
# Ru 115
# Sl 8
# V 78
# Ru 176
# Harvard 10
# Ru 116
# Ru 117
# Ru 118
# Ru 119
# Hogg 19
# Harvard 11
# ESO 10 2
# Mel 227
# B 42
# B 43
# Do 27
# B 44
# He 2180
# B 45
# Abell 40
# Gcl 48
# B 46
# B 47
# Pal 15
# Gcl 53
# B 51
# Gcl 54
# B 57
# B 244
# Gcl 55
# B 59
# B 60
# Nassau 1
# Gcl 56
# B 61
# B 62
# B 63
# Gcl 57
# B 64
# Gcl 58
# B 65
# B 66
# B 67
# Gcl 61
# PK 2 81
# B 259
# B 256
# B 67a
# B 68
# B 69
# Haro 2 7
# B 70
# B 72
# Gcl 62
# Gcl 63
# B 76
# B 74
# B 75
# Gcl 65
# B 77
# Tr 26
# H Iv 11
# Hp 1
# The 326
# Abell 42
# B 268
# B 270
# B 78
# Gcl 73
# B 79
# B 276
# Hubble 4
# Pal 6
# Gcl 76
# The 42
# Cr 350
# Abell 43
# Cr 359
# Gcl 81
# Cannon 31
# J 320
# Abell 539
# Ced 44
# Do 17
# DoDz 2
# Do 19
# 113 Taurus
# Cr 458
# B 225
# B 30
# Abell 10
# B 31
# B 32
# Berk 20
# Cr 69
# Ced 55B
# Ced 55C
# Cr 70
# Abell 11
# Ced 55K
# B 33
# Ced 55P
# Ced 55Q
# Ced 59
# B 35
# B 36
# Dg 79
# Cr 74
# Berk 72
# Berk 21
# Basel 11B
# Berk 22
# Abell 12
# Abell 13
# Ced 62
# Ced 62
# Ced 67A
# Lund 1182
# Abell 14
# ESO 103 2
# Dunlop 295
# NGC 2
# MCG 254 2
# V 84
# Pal 13
# Pegasus Dwarf
# Jones 1
# Abell 2634
# Abell 2666
# Stock 4
# Basel 10
# Tr 2
# Abell 4
# Abell 5
# MCG 7 2
# Abell 407
# King 5
# Perseus I
# Mel 20
# B 205
# Berk 9
# B 1
# B 2
# B 3
# B 4
# B 5
# Kr 21
# King 7
# Berk 11
# B 15
# B 16
# B 17
# B 20
# Berk 67
# Berk 12
# Berk 68
# Ru 148
# Am 0007571
# ESO 205 2
# DDO 2
# MCG 0 2 49
# MCG 0 2 50
# MCG 0 2 52
# MCG 0 2 89
# MCG 1 2 42
# Iv Zw 35
# Arp 331
# Arp 331
# Arp 331
# Arp 331
# Arp 164
# And Ii
# MCG 2 4 23
# Abell 194
# Arp 306A
# Iii Zw 99
# Gcl 11
# Cr 135
# Be 135
# Cr 147
# Cr 146
# M4 2
# Ru 22
# Ru 23
# Bochum 4
# Gum 6
# Bochum 6
# Ru 24
# Bochum 5
# Ru 40
# Gum 7
# Ced 101
# Ru 25
# Ru 26
# Cr 155
# Ru 27
# Ru 28
# Ru 151
# Ru 31
# Ru 30
# Abell 23
# Ru 32
# Ru 33
# Ru 34
# Ru 35
# Ru 36
# Ru 37
# Ru 38
# Ru 39
# Ru 41
# Ru 152
# Harvard 2
# Ru 42
# MCG 221 2
# Ru 44
# Ru 45
# Ru 153
# Ru 154
# Ru 46
# Ru 47
# Ru 48
# Ru 49
# Ru 50
# Cr 173
# Ru 51
# Ru 52
# Ru 155
# Abell 26
# Ru 53
# Ru 54
# Ru 55
# Ru 56
# Ru 57
# Ru 58
# Pismis 2
# Ru 59
# MCG 222 2
# Cr 185
# Cr 187
# Ru 61
# Ru 157
# Abell 27
# Ru 62
# Abell 29
# Ru 66
# Ru 68
# Cr 196
# Ru 72
# Ru 158
# K1 2
# Ru 74
# ESO 434 2
# Blanco 1
# Dunlop 507
# Sculptor Dwarf
# ESO 470 2
# Be 149
# B 40
# B 41
# Abell 38
# Dunlop 514
# Cr 302
# Gcl 42
# Gcl 43
# Ced 132
# B 231
# Sl 25
# Sl 18
# Sl 15
# Sl 17
# Dunlop 520
# Cr 316
# Tr 24
# Sl 20
# B 50
# Haro 2 1
# B 53
# B 55
# B 56
# Haro 2 3
# B 58
# Gum 58
# B 252
# Bochum 13
# Haro 2 6
# B 257
# Ru 123
# Tr 25
# Gum 59
# Sl 22
# Cannon 13
# Ter 2
# Gum 68
# Antalova 2
# Cr 332
# Harvard 16
# Cr 333
# Sl 26
# Ton 1
# Ru 126
# Sl 28
# Ter 1
# Cr 336
# Gcl 70
# Ton 2
# Tr 28
# Ru 127
# Cr 338
# Cr 343
# Ru 128
# Cr 345
# Ru 132
# Gcl 78
# Ter 6
# Gcl 79
# B 283
# B 287
# Cannon 21
# Harvard 18
# Gcl 80
# Ru 170
# Do 28
# B 95
# B 97
# Abell 44
# Abell 45
# B 312
# Ru 141
# Do 29
# Ru 142
# Ru 144
# Ru 171
# B 100
# B 101
# Ru 143
# Do 30
# V 18
# B 314
# B 103
# Tr 34
# Do 32
# Tr 35
# B 104
# Basel 1
# B 108
# B 318
# B 110
# B 111
# B 112
# B 113
# Gcl 103
# B 114
# B 115
# Abell 49
# B 117a
# B 118
# B 119a
# Pal 5
# Arp 72
# Shane 1
# Abell 41
# K2 5
# Ru 135
# Gcl 83
# Gcl 85
# Gum 80
# Pal 7
# Tr 32
# Cr 386
# Do 33
# Ym 16
# ZwG 8 2
# MCG 026 2
# Sextans B Dwarf
# Pal 3
# Sextans A
# Berk 44
# Pal 10
# Abell 59
# Berk 47
# Abell 63
# Harvard 20
# B 83a
# Cr 347
# B 84
# Gum 70
# Ru 130
# Hubble 5
# Ter 5
# Gcl 77
# Ru 131
# H Ii 586
# Cr 351
# The 45
# Basel 5
# Ru 133
# Ru 134
# Ru 168
# Hubble 6
# The 410
# B 84a
# PK 2 11
# PK 2 22
# Ru 136
# Tr 31
# Ru 137
# Ru 138
# Ru 139
# PK 2 24
# Djorgovski 2
# Ter 9
# Bochum 14
# B 85
# B 86
# Gcl 82
# Ter 10
# B 88
# B 87
# PK 2 32
# Gcl 84
# B 89
# PK 2 35
# Cr 468
# PK 2 41
# Gcl 87
# B 303
# Gcl 88
# Cr 367
# B 91
# B 90
# Gcl 89
# PK 2 42
# Gcl 91
# PK 2 51
# PK 2 61
# B 92
# Gum 79
# PK 2 62
# Cr 469
# B 93
# Gum 78
# Ru 140
# PK 2 71
# Gcl 93
# Cr 378
# H Ii 204
# Cannon 15
# Gcl 95
# Gcl 97
# B 98
# Gcl 98
# Pal 8
# Ru 145
# Cr 394
# Pal 9
# Hubble 7
# Dunlop 573
# Abell 51
# Hubble 8
# Ru 147
# Abell 60
# Arp 2
# K2 7
# Abell 65
# Abell 66
# New 5
# Ced 19c
# Ced 19e
# Ced 19h
# Ced 19I
# Ced 19o
# Ced 19p
# Do 14
# B 7
# B 10
# Dg 31
# Be 84
# Hyades
# Ced 33
# Ced 34
# B 18
# B 22
# B 23
# B 24
# Dunlop 376
# ESO 186 2
# Cr 21
# 47 Tucanae
# Small Magellanc Cl
# Dunlop 62
# Holmberg Ii
# Abell 28
# Holmberg I
# Arp 148
# Arp 105
# Abell 1213
# Abell 1228
# Pal 4
# Abell 1314
# Arp 280b
# Ursa Major I
# Cr 285
# Holmberg Iv
# MCG 1214 2
# Ursa Minor Dwarf
# Pb 2
# Ru 60
# Gum 12
# Ru 63
# Ru 64
# Ru 65
# Cr 191
# Waterloo 6
# Ru 67
# Cr 192
# Cr 197
# Bochum 7
# Gum 15
# Ru 69
# Cr 203
# Ru 70
# Ru 71
# Sl 4
# Pb 3
# Gum 23
# Cr 205
# Ru 73
# Gum 35
# Pb 4
# Pb 5
# Cr 207
# Ru 75
# Ru 76
# Ru 77
# Cr 208
# Ru 78
# Perek 2 4
# Ru 79
# Ru 80
# Ru 81
# Ru 82
# Ru 83
# Hogg 2
# Cr 213
# Ru 160
# Hogg 3
# Hogg 4
# Ru 85
# Ru 87
# Dunlop 445
# Wilds Triplet
# Ho 320b
# Ho 358a
# Ho 359c
# Ho 365a
# Ho 375a
# Ho 375b
# Ho 381a
# Ho 381b
# Ho 380a
# Ho 382a
# Ho 382b
# Ho 388a
# Ho 403d
# Ho 412a
# Ho 413c
# I Zw 38
# R 80
# Ho 418b
# Ho 420b
# Holmberg Vii
# Ho 436b
# New 3
# Ho 486a
# Ho 486b
# New 4
# MCG 134 2
# ZwG 17 2
# Abell 36
# MCG 036 2
# Gcl 28
# Arp 274
# MCG 038 2
# Abell 54
# Abell 57
# Cr 399
# Ced 16
# Stock 1
# Sg 3148
# Roslund 2
# Berk 48
# Abell 68
# Berk 83
# Ced 175
# Berk 52
# Abell 74
# Sagittarius A East
# Kepler
# Milne 56
# Nrao 593
# Nrao 611
# Da 495
# Cygnus Loop
# Gamma Cygni Snr
# Da 530
# Da 551
# Cassiopeia A
# Cta 1
# Tycho
# Crab Nebula
# Monoceros Nebula
# Pks 064606
# Puppis A
# Vela Xyz
# Rx J085204622
# Msh 1053
# Msh 1161A
# Msh 1162
# Msh 1154
# Pks 12095152
# Msh 1463
# Msh 1457
# Msh 1552
# Msh 1556
# Pks 145941
# Msh 1557
# Lupus Loop
# Msh 1651
# Rx J171373946
# Msh 1739
# 33 Pisces
# 86 Pegasus
# 10 Cassiopeia
# Alpheratz
# Caph
# 87 Pegasus
# Eps Phoenix
# 34 Pisces
# 22 Andromeda
# 6 Cetus
# The Sculptor
# Algenib
# 23 Andromeda
# 89Chi Pegasus
# 7 Cetus
# 35 Pisces
# 36 Pisces
# 24The Andromeda
# 25Sig Andromeda
# 26 Andromeda
# 8Iot Cetus
# Zet Tucana
# 41 Pisces
# 27Rho Andromeda
# Pi Tucana
# Iot Sculptor
# 42 Pisces
# 9 Cetus
# 12 Cassiopeia
# 44 Pisces
# Bet Hydrus
# Alp Phoenix
# Kap Phoenix
# 10 Cetus
# 47 Pisces
# Eta Sculptor
# 48 Pisces
# 28 Andromeda
# 12 Cetus
# 13 Cassiopeia
# 14Lam Cassiopeia
# 15Kap Cassiopeia
# 52 Pisces
# 51 Pisces
# 16 Cassiopeia
# The Tucana
# 13 Cetus
# 14 Cetus
# 29Pi Andromeda
# 53 Pisces
# 30Eps Andromeda
# 31Del Andromeda
# 54 Pisces
# 55 Pisces
# Schedar
# 32 Andromeda
# 19Xi Cassiopeia
# Mu Phoenix
# Xi Phoenix
# 20Pi Cassiopeia
# Rho Tucana
# 16Bet Cetus
# Eta Phoenix
# 21 Cassiopeia
# 22Omi Cassiopeia
# 18 Cetus
# 23 Cassiopeia
# 57 Pisces
# 58 Pisces
# 59 Pisces
# 34Zet Andromeda
# 60 Pisces
# 61 Pisces
# 24Eta Cassiopeia
# 62 Pisces
# 25Nu Cassiopeia
# 63Del Pisces
# 64 Pisces
# 35Nu Andromeda
# 65 Pisces
# 65 Pisces
# Lam Hydrus
# Rho Phoenix
# 20 Cetus
# 66 Pisces
# 21 Cetus
# 36 Andromeda
# 67 Pisces
# 27Gam Cassiopeia
# 37Mu Andromeda
# 38Eta Andromeda
# 68 Pisces
# Alp Sculptor
# Xi Sculptor
# 39 Andromeda
# 69Sig Pisces
# Sig Sculptor
# 71Eps Pisces
# Ome Phoenix
# 25 Cetus
# 26 Cetus
# 73 Pisces
# 72 Pisces
# 77 Pisces
# 77 Pisces
# 27 Cetus
# 28 Cetus
# 75 Pisces
# 30Mu Cassiopeia
# Bet Phoenix
# 41 Andromeda
# 78 Pisces
# 30 Cetus
# 80 Pisces
# Ups Phoenix
# Iot Tucana
# 31Eta Cetus
# 42Phi Andromeda
# 31 Cassiopeia
# Mirach
# Zet Phoenix
# 44 Andromeda
# 33The Cassiopeia
# 32 Cassiopeia
# 32 Cetus
# 33 Cetus
# 45 Andromeda
# 82 Pisces
# 84Chi Pisces
# 83Tau Pisces
# 34 Cetus
# 85Phi Pisces
# 86Zet Pisces
# 87 Pisces
# 37 Cetus
# 88 Pisces
# 38 Cetus
# Nu Phoenix
# 39 Cetus
# Kap Tucana
# 89 Pisces
# 34Phi Cassiopeia
# 90Ups Pisces
# 35 Cassiopeia
# 42 Cetus
# 91 Pisces
# 43 Cetus
# 47 Andromeda
# 36Psi Cassiopeia
# 44 Cetus
# 45The Cetus
# Ruchbah
# 46 Cetus
# 93Rho Pisces
# 94 Pisces
# 48Ome Andromeda
# 47 Cetus
# Polaris
# 38 Cassiopeia
# Gam Phoenix
# 49 Andromeda
# 97 Pisces
# 48 Cetus
# 98Mu Pisces
# Delphinus Phoenix
# 39Chi Cassiopeia
# 49 Cetus
# 101 Pisces
# 40 Cassiopeia
# 50 Cetus
# Taurus Sculptor
# 102Pi Pisces
# 52Chi Andromeda
# Alp Eridanus
# 105 Pisces
# 53Tau Andromeda
# 43 Cassiopeia
# 42 Cassiopeia
# 106Nu Pisces
# 44 Cassiopeia
# 107 Pisces
# Phi Perseus
# Pi Sculptor
# 109 Pisces
# 52Tau Cetus
# Torcular
# Eps Sculptor
# 4 Aries
# 1 Aries
# 53Chi Cetus
# 1 Perseus
# 2 Perseus
# 55Zet Cetus
# 55 Andromeda
# 46Ome Cassiopeia
# 111Xi Pisces
# Sheratan
# Psi Phoenix
# 56 Andromeda
# Phi Phoenix
# 7 Aries
# 8Iot Aries
# 56 Cetus
# Chi Eridanus
# 3 Perseus
# 9Lam Aries
# 48 Cassiopeia
# 50 Cassiopeia
# 47 Cassiopeia
# 112 Pisces
# 57 Cetus
# 59Ups Cetus
# 52 Cassiopeia
# 53 Cassiopeia
# 4 Perseus
# Alp Hydrus
# 49 Cassiopeia
# Sig Hydrus
# Pi Fornax
# 3Eps Triangulum
# Chi Phoenix
# Almach
# 10 Aries
# 60 Cetus
# 61 Cetus
# Nu Fornax
# 12Kap Aries
# 11 Aries
# Hamal
# 58 Andromeda
# 4Bet Triangulum
# 14 Aries
# 5 Perseus
# 59 Andromeda
# 59 Andromeda
# 15 Aries
# 16 Aries
# 5 Triangulum
# 64 Cetus
# 63 Cetus
# 55 Cassiopeia
# 6 Triangulum
# 60 Andromeda
# 17Eta Aries
# 19 Aries
# 66 Cetus
# Mu Fornax
# 7 Triangulum
# 20 Aries
# 21 Aries
# 8Del Triangulum
# 8 Perseus
# 7 Perseus
# 9Gam Triangulum
# 67 Cetus
# Pi 1Hyi
# 22The Aries
# 62 Andromeda
# Phi Eridanus
# 10 Triangulum
# Pi 2Hyi
# 68Omi Cetus
# 63 Andromeda
# 9 Perseus
# 69 Cetus
# 70 Cetus
# 64 Andromeda
# Kap Fornax
# 10 Perseus
# 65 Andromeda
# 24Xi Aries
# 71 Cetus
# Delphinus Hydrus
# Iot Cassiopeia
# 72Rho Cetus
# 66 Andromeda
# 11 Triangulum
# Lam Horologium
# Kap Hydrus
# 12 Triangulum
# 13 Triangulum
# Kap Eridanus
# Phi Fornax
# 26 Aries
# 27 Aries
# 14 Triangulum
# 75 Cetus
# 76Sig Cetus
# 29 Aries
# Ome Fornax
# 15 Triangulum
# 77 Cetus
# 78Nu Cetus
# 80 Cetus
# 31 Aries
# 30 Aries
# 30 Aries
# 81 Cetus
# 32Nu Aries
# Mu Hydrus
# Eta Horologium
# 82Del Cetus
# 83Eps Cetus
# 33 Aries
# 11 Perseus
# 12 Perseus
# 84 Cetus
# 34Mu Aries
# Iot Eridanus
# 13The Perseus
# 14 Perseus
# 35 Aries
# Zet Horologium
# Eps Hydrus
# 36 Aries
# 37Omi Aries
# Iot Horologium
# 89Pi Cetus
# 38 Aries
# 87Mu Cetus
# 40 Aries
# Gam Horologium
# 42Pi Aries
# Zet Hydrus
# 16 Perseus
# Bet Fornax
# 17 Perseus
# 43Sig Aries
# Nu Horologium
# 18Tau Perseus
# 20 Perseus
# Psi Fornax
# Nu Hydrus
# 21 Perseus
# 3Eta Eridanus
# 1080
# 47 Aries
# 22Pi Perseus
# 24 Perseus
# 4 Eridanus
# 48Eps Aries
# 6 Eridanus
# 91Lam Cetus
# 5 Eridanus
# Zet Fornax
# 7 Eridanus
# 49 Aries
# Bet Horologium
# 93 Cetus
# Menkar
# Eps Fornax
# 23Gam Perseus
# 25Rho Perseus
# 52 Aries
# Mu Horologium
# Algol
# Iot Perseus
# 53 Aries
# The Hydrus
# 54 Aries
# 27Kap Perseus
# 55 Aries
# 28Ome Perseus
# Botein
# 56 Aries
# 94 Cetus
# Alp Fornax
# 58Zet Aries
# 30 Perseus
# 13Zet Eridanus
# 29 Perseus
# 14 Eridanus
# 31 Perseus
# 95 Cetus
# 15 Eridanus
# 59 Aries
# 60 Aries
# 32 Perseus
# 62 Aries
# Mirfak
# 64 Aries
# Iot Hydrus
# 65 Aries
# 1Omi Taurus
# 2Xi Taurus
# 34 Perseus
# 66 Aries
# 35Sig Perseus
# 4 Taurus
# 5 Taurus
# 36 Perseus
# 17 Eridanus
# 6 Taurus
# Kap Reticulum
# 18Eps Eridanus
# 7 Taurus
# 37Psi Perseus
# 20 Eridanus
# 10 Taurus
# 21 Eridanus
# Taurus Fornax
# 12 Taurus
# 11 Taurus
# 22 Eridanus
# 39Del Perseus
# 40 Perseus
# 13 Taurus
# Atik
# 14 Taurus
# Delphinus Fornax
# 41Nu Perseus
# 23Del Eridanus
# Celaeno
# Electra
# 18 Taurus
# Taygeta
# 24 Eridanus
# Gam Camelopardalis
# 25 Eridanus
# Asterope
# 22 Taurus
# 29 Taurus
# Merope
# 26Pi Eridanus
# Alcyone
# Sig Fornax
# 30 Taurus
# Bet Reticulum
# 42 Perseus
# Atlas
# Pleione
# Rho Fornax
# 31 Taurus
# 30 Eridanus
# 44Zet Perseus
# Gam Hydrus
# 43 Perseus
# 32 Eridanus
# 32 Eridanus
# 32 Taurus
# 45Eps Perseus
# 33 Taurus
# Menkib
# 34Gam Eridanus
# 35Lam Taurus
# 35 Eridanus
# Delphinus Reticulum
# 38Nu Taurus
# 36 Taurus
# 40 Taurus
# 37 Taurus
# 47Lam Perseus
# 39 Taurus
# Gam Reticulum
# Iot Reticulum
# 41 Taurus
# 42Psi Taurus
# 48 Perseus
# 49 Perseus
# 50 Perseus
# 44 Taurus
# 37 Eridanus
# 45 Taurus
# Delphinus Horologium
# 51Mu Perseus
# 52 Perseus
# 46 Taurus
# 47 Taurus
# 39 Eridanus
# 48 Taurus
# 49Mu Taurus
# Alp Horologium
# 51 Taurus
# Alp Reticulum
# Gam Dorado
# 53 Taurus
# 56 Taurus
# 54 Perseus
# Prima Hyadum
# 52Phi Taurus
# 53 Perseus
# 57 Taurus
# Eps Reticulum
# 58 Taurus
# 60 Taurus
# 59Chi Taurus
# The Reticulum
# Secunda Hyadum
# 63 Taurus
# 55 Perseus
# 62 Taurus
# 56 Perseus
# 66 Taurus
# 42Xi Eridanus
# 70 Taurus
# 69Ups Taurus
# 43 Eridanus
# 71 Taurus
# Eta Reticulum
# 73Pi Taurus
# 72 Taurus
# 75 Taurus
# 76 Taurus
# 74Eps Taurus
# 79 Taurus
# 1 Camelopardalis
# 80 Taurus
# Delphinus Mensa
# 81 Taurus
# 83 Taurus
# 85 Taurus
# 57 Perseus
# 45 Eridanus
# Delphinus Caelum
# 86Rho Taurus
# 46 Eridanus
# 47 Eridanus
# 58 Perseus
# Nu Mensa
# Aldebaran
# 88 Taurus
# 48Nu Eridanus
# Alp Dorado
# 2 Camelopardalis
# 3 Camelopardalis
# 89 Taurus
# 90 Taurus
# 51 Eridanus
# 53 Eridanus
# 93 Taurus
# 59 Perseus
# 54 Eridanus
# 94Tau Taurus
# 95 Taurus
# Alp Caelum
# Bet Caelum
# 55 Eridanus
# 55 Eridanus
# 56 Eridanus
# 4 Camelopardalis
# Lam Pictor
# 57Mu Eridanus
# Kap Dorado
# 58 Eridanus
# 96 Taurus
# 59 Eridanus
# Zet Caelum
# Mu Mensa
# 9Alp Camelopardalis
# 97 Taurus
# 60 Eridanus
# 2 Auriga
# 5 Camelopardalis
# 61Ome Eridanus
# 5 Orion
# Iot Pictor
# Iot Pictor
# 7 Camelopardalis
# 6 Orion
# 62 Eridanus
# 99 Taurus
# 8 Camelopardalis
# 98 Taurus
# 4Ome Auriga
# 5 Auriga
# 6 Auriga
# 10Bet Camelopardalis
# 63 Eridanus
# 64 Eridanus
# 65Psi Eridanus
# 102Iot Taurus
# 11 Camelopardalis
# 12 Camelopardalis
# Eta Mensa
# 1 Lepus
# 9 Auriga
# 11 Orion
# 2Eps Lepus
# 104 Taurus
# 66 Eridanus
# 106 Taurus
# 103 Taurus
# 105 Taurus
# 13 Orion
# 14 Orion
# 67Bet Eridanus
# 16 Orion
# 68 Eridanus
# Zet Dorado
# 15 Orion
# Bet Mensa
# 14 Camelopardalis
# 69Lam Eridanus
# 11Mu Auriga
# 3Iot Lepus
# 17Rho Orion
# 5Mu Lepus
# 4Kap Lepus
# 14 Auriga
# Capella
# 108 Taurus
# 19Bet Orion
# Xi Mensa
# 18 Orion
# 15 Camelopardalis
# 16 Auriga
# 17 Auriga
# 15Lam Auriga
# 18 Auriga
# 20Tau Orion
# 109 Taurus
# 19 Auriga
# Omi Columba
# The Dorado
# 21 Orion
# 20Rho Auriga
# 16 Camelopardalis
# 6Lam Lepus
# 7Nu Lepus
# 22 Orion
# Zet Pictor
# 22 Auriga
# 23 Orion
# 21Sig Auriga
# 110 Taurus
# 111 Taurus
# 8 Lepus
# 29 Orion
# 27 Orion
# 28Eta Orion
# Bellatrix
# Kap Pictor
# 17 Camelopardalis
# 24Phi Auriga
# 115 Taurus
# 114 Taurus
# 116 Taurus
# 117 Taurus
# The Pictor
# 118 Taurus
# 18 Camelopardalis
# 9Bet Lepus
# 31 Orion
# Lam Dorado
# 32 Orion
# 33 Orion
# 25Chi Auriga
# 119 Taurus
# 10 Lepus
# 34Del Orion
# 34Del Orion
# 36Ups Orion
# 19 Camelopardalis
# 120 Taurus
# Eps Columba
# 35 Orion
# 11Alp Lepus
# 38 Orion
# 121 Taurus
# Meissa
# 39Lam Orion
# 42 Orion
# 45 Orion
# 122 Taurus
# 26 Auriga
# Bet Dorado
# Nu 1Col
# 125 Taurus
# 48Sig Orion
# 47Ome Orion
# Nu 2Col
# 49 Orion
# 24 Camelopardalis
# 23 Camelopardalis
# 126 Taurus
# 50Zet Orion
# Gam Mensa
# Alp Columba
# 51 Orion
# 12 Lepus
# 26 Camelopardalis
# 27Omi Auriga
# 13Gam Lepus
# 129 Taurus
# 131 Taurus
# 130 Taurus
# Iot Mensa
# 29 Camelopardalis
# 133 Taurus
# 29Tau Auriga
# Mu Columba
# 14Zet Lepus
# 52 Orion
# 132 Taurus
# 53Kap Orion
# 30 Camelopardalis
# 134 Taurus
# 31Ups Auriga
# 32Nu Auriga
# Delphinus Dorado
# 135 Taurus
# Bet Pictor
# Pi Mensa
# 31 Camelopardalis
# 30Xi Auriga
# 55 Orion
# 137 Taurus
# 136 Taurus
# 15Del Lepus
# 56 Orion
# Bet Columba
# Gam Pictor
# 57 Orion
# Lam Columba
# Betelgeuse
# Lam Mensa
# Eps Dorado
# 33Del Auriga
# 139 Taurus
# 16Eta Lepus
# Xi Columba
# Menkalinan
# 35Pi Auriga
# Sig Columba
# 59 Orion
# 36 Auriga
# 60 Orion
# Gam Columba
# 1 Monoceros
# 2 Monoceros
# 38 Auriga
# Eta Columba
# 61Mu Orion
# Kap Mensa
# 64 Orion
# 39 Auriga
# 1 Gemini
# 40 Auriga
# 63 Orion
# 66 Orion
# 17 Lepus
# 37 Camelopardalis
# 18The Lepus
# 67Nu Orion
# 36 Camelopardalis
# 19 Lepus
# Pi 1Col
# 3 Gemini
# 41 Auriga
# 41 Auriga
# The Columba
# Pi 2Col
# 5 Gemini
# 68 Orion
# 6 Gemini
# 69 Orion
# 70Xi Orion
# 40 Camelopardalis
# Delphinus Pictor
# 1 Lynx
# Propus
# 44Kap Auriga
# 71 Orion
# Nu Dorado
# 72 Orion
# 5Gam Monoceros
# 42 Auriga
# 73 Orion
# 8 Gemini
# 2 Lynx
# 43 Auriga
# 9 Gemini
# 74 Orion
# 75 Orion
# 6 Monoceros
# Kap Columba
# 4 Lynx
# Alp Mensa
# 45 Auriga
# 7 Monoceros
# 1Zet Canis Major
# 5 Lynx
# 2Bet Canis Major
# Delphinus Columba
# 8Eps Monoceros
# Nu Pictor
# Alp Carina
# 16 Gemini
# 6 Lynx
# 48 Auriga
# 47 Auriga
# 18Nu Gemini
# 10 Monoceros
# Pi 1Dor
# 11Bet Monoceros
# 11Bet Monoceros
# Lam Canis Major
# 19 Gemini
# 7 Lynx
# Pi 2Dor
# 12 Monoceros
# 13 Monoceros
# 8 Lynx
# 49 Auriga
# 11 Lynx
# 14 Monoceros
# Mu Pictor
# 51 Auriga
# Alhena
# 53 Auriga
# 54 Auriga
# Nu Puppis
# 25 Gemini
# 26 Gemini
# 12 Lynx
# Mebsuta
# 13 Lynx
# 30 Gemini
# 28 Gemini
# 32 Gemini
# 42 Camelopardalis
# 9Alp Canis Major
# 10 Canis Major
# 16 Monoceros
# 17 Monoceros
# 11 Canis Major
# 18 Monoceros
# 12 Canis Major
# 43 Camelopardalis
# 33 Gemini
# 14 Lynx
# 35 Gemini
# 36 Gemini
# 13Kap Canis Major
# 59 Auriga
# 34The Gemini
# 60 Auriga
# Alp Pictor
# Taurus Puppis
# Zet Mensa
# 15 Lynx
# 38 Gemini
# 37 Gemini
# 15 Canis Major
# 14The Canis Major
# 16 Lynx
# 17 Canis Major
# 19Pi Canis Major
# 18Mu Canis Major
# 20Iot Canis Major
# 62 Auriga
# 39 Gemini
# Iot Volans
# 40 Gemini
# 41 Gemini
# 21Eps Canis Major
# 42Ome Gemini
# 22Sig Canis Major
# 19 Monoceros
# Mekbuda
# 23Gam Canis Major
# 44 Gemini
# 45 Gemini
# The Mensa
# 25Del Canis Major
# 63 Auriga
# 46Tau Gemini
# 47 Gemini
# 20 Monoceros
# 48 Gemini
# 21 Monoceros
# 22Del Monoceros
# 18 Lynx
# 51 Gemini
# 26 Canis Major
# 52 Gemini
# 53 Gemini
# 24 Monoceros
# 27 Canis Major
# 28Ome Canis Major
# 64 Auriga
# 54Lam Gemini
# 47 Camelopardalis
# Pi Puppis
# Wasat
# 29 Canis Major
# 19 Lynx
# 19 Lynx
# 65 Auriga
# 56 Gemini
# Delphinus Volans
# 66 Auriga
# 57 Gemini
# 58 Gemini
# 59 Gemini
# 21 Lynx
# 1 Canis Minor
# 60Iot Gemini
# 31Eta Canis Major
# 2Eps Canis Minor
# 61 Gemini
# Gomeisa
# 63 Gemini
# 22 Lynx
# 5Eta Canis Minor
# 62Rho Gemini
# 4Gam Canis Minor
# 64 Gemini
# 65 Gemini
# 6 Canis Minor
# Sig Puppis
# 68 Gemini
# 66Alp Gemini
# 69Ups Gemini
# Eps Mensa
# 70 Gemini
# 25 Monoceros
# 23 Lynx
# 71Omi Gemini
# 74 Gemini
# Procyon
# 24 Lynx
# 26Alp Monoceros
# 75Sig Gemini
# 51 Camelopardalis
# 49 Camelopardalis
# 76 Gemini
# 77Kap Gemini
# Pollux
# 79 Gemini
# 1 Puppis
# 3 Puppis
# 81 Gemini
# 11 Canis Minor
# 2 Puppis
# 2 Puppis
# 80Pi Gemini
# 4 Puppis
# 82 Gemini
# Zet Volans
# 5 Puppis
# Omi Puppis
# 6 Puppis
# 7Xi Puppis
# 13Zet Canis Minor
# 8 Puppis
# 9 Puppis
# 25 Lynx
# 26 Lynx
# 83Phi Gemini
# 10 Puppis
# 85 Gemini
# 1 Cancer
# 11 Puppis
# 53 Camelopardalis
# 14 Canis Minor
# Chi Carina
# 27 Monoceros
# 12 Puppis
# 3 Cancer
# 5 Cancer
# 28 Monoceros
# Chi Gemini
# 8 Cancer
# Zet Puppis
# 28 Lynx
# 14 Puppis
# 27 Lynx
# 12 Cancer
# 15Rho Puppis
# 29Zet Monoceros
# 14Psi Cancer
# 16 Puppis
# 18 Puppis
# Tegmine
# 15 Cancer
# Eps Volans
# 20 Puppis
# 29 Lynx
# 30 Lynx
# 21 Puppis
# 18Chi Cancer
# 20 Cancer
# 22 Puppis
# 21 Cancer
# 1 Hydra
# 25 Cancer
# Eps Carina
# 24 Cancer
# 24 Cancer
# Alp Chamaeleon
# 27 Cancer
# 2 Hydra
# 28 Cancer
# 29 Cancer
# Eta Volans
# The Chamaeleon
# Bet Volans
# 2 Ursa Major
# 31The Cancer
# 32 Lynx
# 33Eta Cancer
# 34 Cancer
# 33 Lynx
# 35 Cancer
# 3 Hydra
# 36 Cancer
# 4Del Hydra
# 37 Cancer
# Eta Pyxis
# 34 Lynx
# 39 Cancer
# 6 Hydra
# Zet Pyxis
# Bet Pyxis
# 9 Hydra
# Asellus Borealis
# 45 Cancer
# 7Eta Hydra
# The Volans
# Asellus Australis
# 46 Cancer
# 49 Cancer
# Alp Pyxis
# 10 Hydra
# 48Iot Cancer
# 48Iot Cancer
# 50 Cancer
# 12 Hydra
# Delphinus Vela
# 13Rho Hydra
# 14 Hydra
# Eta Chamaeleon
# 5 Ursa Major
# 35 Lynx
# 54 Cancer
# Gam Pyxis
# 53 Cancer
# Copernicus
# 15 Hydra
# 6 Ursa Major
# 57 Cancer
# 16Zet Hydra
# 60 Cancer
# 17 Hydra
# 17 Hydra
# Delphinus Pyxis
# 61 Cancer
# Talitha
# Acubens
# 8Rho Ursa Major
# 66 Cancer
# 67 Cancer
# Alkaphrah
# 69Nu Cancer
# 70 Cancer
# 18Ome Hydra
# Alp Volans
# 15 Ursa Major
# 72Tau Cancer
# 76Kap Cancer
# 14Tau Ursa Major
# 75 Cancer
# Kap Pyxis
# 19 Hydra
# Lam Vela
# 79 Cancer
# 20 Hydra
# Eps Pyxis
# 16 Ursa Major
# 36 Lynx
# 21 Hydra
# 17 Ursa Major
# 18 Ursa Major
# 22The Hydra
# Zet Octans
# 23 Hydra
# 24 Hydra
# Bet Carina
# 38 Lynx
# Iot Carina
# 40Alp Lynx
# 26 Hydra
# 27 Hydra
# The Pyxis
# 1Kap Leo
# Lam Pyxis
# Kap Vela
# 28 Hydra
# 29 Hydra
# 30Alp Hydra
# 2Ome Leo
# 3 Leo
# 23 Ursa Major
# 7 Leo Minor
# Eps Antlia
# 22 Ursa Major
# 8 Leo Minor
# 24 Ursa Major
# 25The Ursa Major
# 6 Leo
# 5Xi Leo
# Psi Vela
# 9 Leo Minor
# Iot Chamaeleon
# 26 Ursa Major
# 10 Leo Minor
# 33 Hydra
# 11 Leo Minor
# 7 Leo
# 8 Leo
# 10 Leo
# 42 Lynx
# 34 Hydra
# 27 Ursa Major
# 35Iot Hydra
# 37 Hydra
# 38Kap Hydra
# 43 Lynx
# Subra
# 13 Leo
# 13 Leo Minor
# Zet Chamaeleon
# 15 Leo
# 28 Ursa Major
# 16Psi Leo
# The Antlia
# 17Eps Leo
# 18 Leo
# 19 Leo
# 29Ups Ursa Major
# 20 Leo
# Ups Carina
# Ups Carina
# 4 Sextans
# 30Phi Ursa Major
# 23 Leo
# 6 Sextans
# 22 Leo
# Nu Chamaeleon
# Rasalas
# 7 Sextans
# 8Gam Sextans
# 31 Ursa Major
# 19 Leo Minor
# 27Nu Leo
# Phi Vela
# 12 Sextans
# Eta Antlia
# 29Pi Leo
# 20 Leo Minor
# 13 Sextans
# 14 Sextans
# 21 Leo Minor
# 30Eta Leo
# 31 Leo
# 15Alp Sextans
# Regulus
# Mu 1Cha
# 17 Sextans
# 41Lam Hydra
# 18 Sextans
# Mu 2Cha
# 34 Leo
# 19 Sextans
# 22 Leo Minor
# 23 Leo Minor
# 32 Ursa Major
# 24 Leo Minor
# 35 Leo
# Adhafera
# Tania Borealis
# 37 Leo
# Ome Carina
# 39 Leo
# 22Eps Sextans
# 40 Leo
# Algieba
# 23 Sextans
# Tania Australis
# 42 Leo
# 27 Leo Minor
# 43 Leo
# 28 Leo Minor
# 25 Sextans
# 44 Leo
# 30 Leo Minor
# 42Mu Hydra
# 31Bet Leo Minor
# 45 Leo
# Alp Antlia
# 35 Ursa Major
# 36 Ursa Major
# 32 Leo Minor
# 29Del Sextans
# Delphinus Antlia
# 30Bet Sextans
# 33 Leo Minor
# 46 Leo
# 47Rho Leo
# 34 Leo Minor
# 37 Ursa Major
# 44 Hydra
# 48 Leo
# 49 Leo
# 35 Leo Minor
# 37 Leo Minor
# 38 Leo Minor
# Gam Chamaeleon
# 38 Ursa Major
# 33 Sextans
# 39 Ursa Major
# 40 Leo Minor
# 41 Leo Minor
# 35 Sextans
# 36 Sextans
# 41 Ursa Major
# 42 Leo Minor
# 51 Leo
# 52 Leo
# Eta Carina
# Mu Vela
# 43 Leo Minor
# 53 Leo
# 40 Sextans
# 44 Leo Minor
# Nu Hydra
# 43 Ursa Major
# 42 Ursa Major
# 41 Sextans
# 44 Ursa Major
# 45Ome Ursa Major
# 48 Leo Minor
# 46 Ursa Major
# 54 Leo
# 54 Leo
# 55 Leo
# 56 Leo
# 50 Leo Minor
# Iot Antlia
# 7Alp Crater
# 49 Ursa Major
# 58 Leo
# 59 Leo
# Merak
# 61 Leo
# 60 Leo
# Dubhe
# 62 Leo
# 51 Ursa Major
# 63Chi Leo
# Eta Octans
# 65 Leo
# 64 Leo
# 67 Leo
# 52Psi Ursa Major
# 11Bet Crater
# Psi Crater
# 69 Leo
# Zosma
# 72 Leo
# 73 Leo
# 74Phi Leo
# 75 Leo
# Alula Australis
# Alula Borealis
# 55 Ursa Major
# 76 Leo
# 12Del Crater
# 77Sig Leo
# Pi Centaurus
# 56 Ursa Major
# 13Lam Crater
# 78Iot Leo
# 79 Leo
# 14Eps Crater
# 15Gam Crater
# 81 Leo
# 80 Leo
# 83 Leo
# 16Kap Crater
# 84Tau Leo
# 57 Ursa Major
# 85 Leo
# 58 Ursa Major
# 87 Leo
# 86 Leo
# 88 Leo
# Xi Hydra
# 89 Leo
# 90 Leo
# Formosa
# 2 Draco
# 21The Crater
# 91Ups Leo
# 59 Ursa Major
# Pi Chamaeleon
# 60 Ursa Major
# 1Ome Virgo
# 24Iot Crater
# Omi Hydra
# 92 Leo
# 61 Ursa Major
# 62 Ursa Major
# 3 Draco
# 27Zet Crater
# 2Xi Virgo
# 3Nu Virgo
# Lam Musca
# 93 Leo
# 4 Virgo
# Mu Musca
# Denebola
# Zavijava
# Bet Hydra
# Phecda
# 6 Virgo
# 65 Ursa Major
# 65 Ursa Major
# 95 Leo
# 66 Ursa Major
# 30Eta Crater
# Eps Chamaeleon
# 7 Virgo
# 8Pi Virgo
# 67 Ursa Major
# 2 Coma Berenices
# Kap Chamaeleon
# 9Omi Virgo
# Eta Crux
# Delphinus Centaurus
# 1Alp Corvus
# 10 Virgo
# 11 Virgo
# 2Eps Corvus
# 3 Coma Berenices
# 3 Corvus
# Rho Centaurus
# 4 Coma Berenices
# 68 Ursa Major
# 5 Coma Berenices
# 12 Virgo
# Delphinus Crux
# Megrez
# 4Gam Corvus
# 6 Coma Berenices
# 2 Canes Venatici
# 7 Coma Berenices
# Eps Musca
# Bet Chamaeleon
# Zet Crux
# 13 Virgo
# 8 Coma Berenices
# 9 Coma Berenices
# 15Eta Virgo
# 3 Canes Venatici
# 16 Virgo
# 5Zet Corvus
# 11 Coma Berenices
# Eps Crux
# 70 Ursa Major
# 12 Coma Berenices
# 17 Virgo
# 6 Corvus
# 4 Canes Venatici
# 5 Canes Venatici
# 13 Coma Berenices
# 71 Ursa Major
# 6 Canes Venatici
# 14 Coma Berenices
# 15Gam Coma Berenices
# 16 Coma Berenices
# Sig Centaurus
# 73 Ursa Major
# 17 Coma Berenices
# 18 Coma Berenices
# 20 Coma Berenices
# 7Del Corvus
# 74 Ursa Major
# 7 Canes Venatici
# 75 Ursa Major
# Gam Crux
# Gam Crux
# 4 Draco
# 21 Coma Berenices
# Gam Musca
# 8Eta Corvus
# 20 Virgo
# 22 Coma Berenices
# 21 Virgo
# Chara
# 9Bet Corvus
# 5Kap Draco
# 23 Coma Berenices
# 24 Coma Berenices
# 24 Coma Berenices
# 6 Draco
# Alp Musca
# 25 Virgo
# 25 Coma Berenices
# Taurus Centaurus
# 9 Canes Venatici
# 26Chi Virgo
# 26 Coma Berenices
# Gam Centaurus
# 27 Virgo
# 29Gam Virgo
# 30Rho Virgo
# 31 Virgo
# 76 Ursa Major
# Iot Crux
# Bet Musca
# 10 Canes Venatici
# La Superba
# 32 Virgo
# 33 Virgo
# 27 Coma Berenices
# Bet Crux
# 34 Virgo
# 35 Virgo
# 28 Coma Berenices
# 29 Coma Berenices
# 11 Canes Venatici
# 30 Coma Berenices
# Iot Octans
# 37 Virgo
# 31 Coma Berenices
# 32 Coma Berenices
# Kap Crux
# 38 Virgo
# 35 Coma Berenices
# Lam Crux
# Mu 1Cru
# Mu 2Cru
# 41 Virgo
# 40Psi Virgo
# Alioth
# Cor Caroli
# 36 Coma Berenices
# 44 Virgo
# Delphinus Musca
# 37 Coma Berenices
# 46 Virgo
# 9 Draco
# 38 Coma Berenices
# 78 Ursa Major
# Vindemiatrix
# Xi 1Cen
# 48 Virgo
# Xi 2Cen
# 14 Canes Venatici
# 39 Coma Berenices
# 40 Coma Berenices
# The Musca
# 41 Coma Berenices
# 49 Virgo
# 45Psi Hydra
# 50 Virgo
# 51The Virgo
# 15 Canes Venatici
# Diadem
# 17 Canes Venatici
# 53 Virgo
# 43Bet Coma Berenices
# 54 Virgo
# Eta Musca
# 55 Virgo
# 57 Virgo
# 19 Canes Venatici
# 59 Virgo
# 60Sig Virgo
# 20 Canes Venatici
# 61 Virgo
# 46Gam Hydra
# 21 Canes Venatici
# Iot Centaurus
# 23 Canes Venatici
# 64 Virgo
# 63 Virgo
# 65 Virgo
# 66 Virgo
# Mizar
# 79Zet Ursa Major
# 67Alp Virgo
# Alcor
# 68 Virgo
# 69 Virgo
# 70 Virgo
# 71 Virgo
# Kap Octans
# 72 Virgo
# 73 Virgo
# 74 Virgo
# 75 Virgo
# 76 Virgo
# 78 Virgo
# 79Zet Virgo
# 81 Ursa Major
# 80 Virgo
# 24 Canes Venatici
# 25 Canes Venatici
# Eps Centaurus
# 82 Ursa Major
# 1 Bootes
# 2 Bootes
# 82 Virgo
# 83 Ursa Major
# 84 Virgo
# 83 Virgo
# 1 Centaurus
# 85 Virgo
# 86 Virgo
# 87 Virgo
# 3 Bootes
# 4Tau Bootes
# 84 Ursa Major
# Nu Centaurus
# Alkaid
# 2 Centaurus
# Mu Centaurus
# 89 Virgo
# 5Ups Bootes
# 6 Bootes
# 3 Centaurus
# 3 Centaurus
# 4 Centaurus
# 7 Bootes
# 10 Draco
# Zet Centaurus
# 90 Virgo
# Muphrid
# 86 Ursa Major
# 92 Virgo
# 9 Bootes
# Phi Centaurus
# 47 Hydra
# 10 Bootes
# 48 Hydra
# The Apus
# 11 Bootes
# 93Tau Virgo
# Bet Centaurus
# Chi Centaurus
# 49Pi Hydra
# 5The Centaurus
# 95 Virgo
# Thuban
# 96 Virgo
# 13 Bootes
# Eta Apus
# 12 Bootes
# 3 Ursa Minor
# 50 Hydra
# 98Kap Virgo
# 4 Ursa Minor
# 14 Bootes
# 15 Bootes
# Eps Apus
# 99Iot Virgo
# Delphinus Octans
# Arcturus
# 21Iot Bootes
# Iot Lupus
# 100Lam Virgo
# 18 Bootes
# 102Ups Virgo
# Psi Centaurus
# 20 Bootes
# 51 Hydra
# 2 Libra
# 23The Bootes
# 22 Bootes
# 104 Virgo
# 52 Hydra
# 105Phi Virgo
# 106 Virgo
# 24 Bootes
# Sig Lupus
# 25Rho Bootes
# 5 Ursa Minor
# 26 Bootes
# Seginus
# Eta Centaurus
# 28Sig Bootes
# Rho Lupus
# Alp Circinus
# 33 Bootes
# Alp Lupus
# Alp Apus
# 30Zet Bootes
# 31 Bootes
# 32 Bootes
# 4 Libra
# 107Mu Virgo
# 34 Bootes
# 54 Hydra
# 108 Virgo
# 35Omi Bootes
# 5 Libra
# 36Eps Bootes
# Izar
# 109 Virgo
# 55 Hydra
# 56 Hydra
# 57 Hydra
# 7Mu Libra
# Pi 1Oct
# 58 Hydra
# Omi Lupus
# 11 Libra
# 39 Bootes
# Zet Circinus
# 37Xi Bootes
# Pi 2Oct
# 12 Libra
# The Circinus
# Ome Octans
# Kochab
# 16 Libra
# Bet Lupus
# Kap Centaurus
# 59 Hydra
# 17 Libra
# 18 Libra
# 19Del Libra
# 40 Bootes
# 60 Hydra
# Eta Circinus
# 41Ome Bootes
# 110 Virgo
# Nekkar
# 20Sig Libra
# Pi Lupus
# 43Psi Bootes
# 44 Bootes
# 21Nu Libra
# Lam Lupus
# 47 Bootes
# 45 Bootes
# 46 Bootes
# Zet Lupus
# 23 Libra
# 1 Lupus
# 26 Libra
# Delphinus Circinus
# Eps Circinus
# Bet Circinus
# Gam Triangulum Australe
# 3 Serpens Cauda
# 48Chi Bootes
# 4 Serpens Cauda
# 49Del Bootes
# Mu Lupus
# 27Bet Libra
# 2 Lupus
# 5 Serpens Cauda
# Delphinus Lupus
# Nu 1Lup
# Nu 2Lup
# 28 Libra
# 29Omi Libra
# Gam Circinus
# Eps Lupus
# 1Omi Corona Borealis
# 6 Serpens Cauda
# 11 Ursa Minor
# 7 Serpens Cauda
# 50 Bootes
# Ups Lupus
# 8 Serpens Cauda
# 31Eps Libra
# 2Eta Corona Borealis
# Rho Octans
# Alkalurops
# Pherkad
# 10 Serpens Cauda
# Nusakan
# Eps Triangulum Australe
# 11 Serpens Cauda
# 36 Libra
# Gam Lupus
# 37 Libra
# 4The Corona Borealis
# 38Gam Libra
# 13Del Serpens Cauda
# 13Del Serpens Cauda
# Alphecca
# 39Ups Libra
# Ome Lupus
# 14 Serpens Cauda
# 6Mu Corona Borealis
# 16 Serpens Cauda
# 40Tau Libra
# 41 Libra
# 54Phi Bootes
# 42 Libra
# 15The Ursa Minor
# 43Kap Libra
# 21Iot Serpens Cauda
# 20Chi Serpens Cauda
# 44Eta Libra
# 8Gam Corona Borealis
# 23Psi Serpens Cauda
# 9Pi Corona Borealis
# 25 Serpens Cauda
# 28Bet Serpens Cauda
# 27Lam Serpens Cauda
# 31Ups Serpens Cauda
# 32Mu Serpens Cauda
# 5Chi Lupus
# 1 Scorpius
# 34Ome Serpens Cauda
# 10Del Corona Borealis
# Kap Triangulum Australe
# 37Eps Serpens Cauda
# 36 Serpens Cauda
# Bet Triangulum Australe
# 38Rho Serpens Cauda
# 11Kap Corona Borealis
# 45Lam Libra
# 16Zet Ursa Minor
# 2 Scorpius
# 46The Libra
# 39 Serpens Cauda
# 3 Scorpius
# 1Chi Hercules
# 47 Libra
# 4 Scorpius
# 40 Serpens Cauda
# Xi 1Lup
# Xi 2Lup
# 5Rho Scorpius
# 2 Hercules
# 41Gam Serpens Cauda
# 12Lam Corona Borealis
# 4 Hercules
# Phi Serpens Cauda
# 48 Libra
# 6Pi Scorpius
# 13Eps Corona Borealis
# Eta Lupus
# 7Del Scorpius
# 49 Libra
# 50 Libra
# Eta Norma
# 5 Hercules
# 15Rho Corona Borealis
# 14Iot Corona Borealis
# 44Pi Serpens Cauda
# 43 Serpens Cauda
# Xi Scorpius
# Delphinus Norma
# 6Ups Hercules
# 13The Draco
# The Lupus
# 11 Scorpius
# 45 Serpens Cauda
# 7Kap Hercules
# 47 Serpens Cauda
# 8 Hercules
# 16Tau Corona Borealis
# Zet Norma
# 11Phi Hercules
# Kap Norma
# 14Nu Scorpius
# 14Nu Scorpius
# 13 Scorpius
# 12 Scorpius
# Delphinus Triangulum Australe
# 15Psi Scorpius
# 16 Scorpius
# 10 Hercules
# The Norma
# 9 Hercules
# 17Chi Scorpius
# 1Del Ophiuchus
# 18 Scorpius
# 17Sig Corona Borealis
# 16 Hercules
# Lam Norma
# 18Ups Corona Borealis
# 2Eps Ophiuchus
# 19 Ursa Minor
# 19Omi Scorpius
# 20 Ursa Minor
# 20Sig Scorpius
# 22Tau Hercules
# 50Sig Serpens Cauda
# 20Gam Hercules
# Zet Triangulum Australe
# Gam Apus
# 19Xi Corona Borealis
# 4Psi Ophiuchus
# Iot Triangulum Australe
# 21 Hercules
# 5Rho Ophiuchus
# 5Rho Ophiuchus
# Eps Norma
# 21Eta Ursa Minor
# Cujam
# 7Chi Ophiuchus
# 25 Hercules
# 3Ups Ophiuchus
# 21Alp Scorpius
# 30 Hercules
# 8Phi Ophiuchus
# Marfik
# The Triangulum Australe
# 9Ome Ophiuchus
# Mu Norma
# 34 Hercules
# 28 Hercules
# 29 Hercules
# 15 Draco
# Bet Apus
# 23Tau Scorpius
# 35Sig Hercules
# 12 Ophiuchus
# 13Zet Ophiuchus
# 16 Draco
# 17 Draco
# 36 Hercules
# 37 Hercules
# 42 Hercules
# 14 Ophiuchus
# 40Zet Hercules
# 39 Hercules
# Alp Triangulum Australe
# 44Eta Hercules
# 18 Draco
# 16 Ophiuchus
# 25 Scorpius
# 43 Hercules
# Eta Ara
# 19 Ophiuchus
# 45 Hercules
# 26Eps Scorpius
# 20 Ophiuchus
# Mu 1Sco
# 47 Hercules
# Mu 2Sco
# 52 Hercules
# 21 Ophiuchus
# 50 Hercules
# 49 Hercules
# 51 Hercules
# 53 Hercules
# 23 Ophiuchus
# 25Iot Ophiuchus
# Zet Ara
# 27 Scorpius
# 24 Ophiuchus
# 56 Hercules
# 54 Hercules
# 27Kap Ophiuchus
# 57 Hercules
# 26 Ophiuchus
# 19 Draco
# 30 Ophiuchus
# 20 Draco
# 29 Ophiuchus
# 22Eps Ursa Minor
# 58Eps Hercules
# 59 Hercules
# 61 Hercules
# 60 Hercules
# 35Eta Ophiuchus
# Eta Scorpius
# 63 Hercules
# 37 Ophiuchus
# 36 Ophiuchus
# 36 Ophiuchus
# Sarin
# Iot Apus
# 41 Ophiuchus
# Zet Apus
# 67Pi Hercules
# 39Omi Ophiuchus
# 39Omi Ophiuchus
# 68 Hercules
# 69 Hercules
# 40Xi Ophiuchus
# 53Nu Serpens Cauda
# Iot Ara
# 42The Ophiuchus
# 70 Hercules
# 72 Hercules
# 43 Ophiuchus
# Bet Ara
# Gam Ara
# 74 Hercules
# Kap Ara
# 73 Hercules
# 75Rho Hercules
# 75Rho Hercules
# 44 Ophiuchus
# 45 Ophiuchus
# 49Sig Ophiuchus
# Delphinus Ara
# 34Ups Scorpius
# 77 Hercules
# Alp Ara
# 51 Ophiuchus
# 35Lam Scorpius
# 78 Hercules
# Rastaban
# 1Sig Ara
# 52 Ophiuchus
# 53 Ophiuchus
# Pi Ara
# The Scorpius
# Rasalhague
# 55Xi Serpens Cauda
# 27 Draco
# 57Mu Ophiuchus
# Lam Ara
# 79 Hercules
# 26 Draco
# 82 Hercules
# Kap Scorpius
# 56Omi Serpens Cauda
# Eta Pavo
# Mu Ara
# 85Iot Hercules
# 58 Ophiuchus
# 28Ome Draco
# 83 Hercules
# Cebalrai
# 84 Hercules
# 61 Ophiuchus
# 3 Sagittarius
# 86Mu Hercules
# 62Gam Ophiuchus
# 87 Hercules
# 30 Draco
# 88 Hercules
# 90 Hercules
# 89 Hercules
# Grumium
# 91The Hercules
# 64Nu Ophiuchus
# 4 Sagittarius
# 35 Draco
# 92Xi Hercules
# 94Nu Hercules
# 57Zet Serpens Cauda
# 66 Ophiuchus
# 93 Hercules
# 67 Ophiuchus
# 6 Sagittarius
# Chi Octans
# 68 Ophiuchus
# 7 Sagittarius
# 95 Hercules
# 95 Hercules
# 69Tau Ophiuchus
# 9 Sagittarius
# 96 Hercules
# 97 Hercules
# The Ara
# Pi Pavo
# 70 Ophiuchus
# Iot Pavo
# 98 Hercules
# 71 Ophiuchus
# 72 Ophiuchus
# 99 Hercules
# 103Omi Hercules
# 100 Hercules
# 100 Hercules
# Eps Telescopium
# 102 Hercules
# Yildun
# 101 Hercules
# 73 Ophiuchus
# 11 Sagittarius
# 40 Draco
# 41 Draco
# 24 Ursa Minor
# 13Mu Sagittarius
# 104 Hercules
# 14 Sagittarius
# 15 Sagittarius
# 16 Sagittarius
# Phi Octans
# Eta Sagittarius
# 36 Draco
# Xi Pavo
# 19Del Sagittarius
# 105 Hercules
# 37 Draco
# 74 Ophiuchus
# 106 Hercules
# 58Eta Serpens Cauda
# 1Kap Lyra
# 108 Hercules
# 107 Hercules
# 20Eps Sagittarius
# Zet Scutum
# 18 Sagittarius
# 109 Hercules
# 21 Sagittarius
# Alp Telescopium
# 2Mu Lyra
# Zet Telescopium
# 22Lam Sagittarius
# Nu Pavo
# 59 Serpens Cauda
# 43Phi Draco
# 39 Draco
# 44Chi Draco
# Gam Scutum
# 60 Serpens Cauda
# Fafnir
# The Corona Australis
# 61 Serpens Cauda
# 24 Sagittarius
# 25 Sagittarius
# Alp Scutum
# 45 Draco
# Zet Pavo
# Vega
# 26 Sagittarius
# Delphinus Scutum
# Lam Corona Australis
# Eps Scutum
# The Pavo
# 27Phi Sagittarius
# 4 Aquila
# 28 Sagittarius
# 46 Draco
# Mu Corona Australis
# 5 Aquila
# 110 Hercules
# Bet Scutum
# 111 Hercules
# Lam Pavo
# 29 Sagittarius
# Kap Telescopium
# 30 Sagittarius
# 8 Aquila
# Kap Pavo
# 112 Hercules
# 33 Sagittarius
# 34Sig Sagittarius
# 50 Draco
# 47Omi Draco
# Ome Pavo
# 113 Hercules
# Lam Telescopium
# Alya
# Eta Scutum
# Eps Corona Australis
# 13 Lyra
# 64 Serpens Cauda
# 10 Aquila
# 11 Aquila
# 48 Draco
# 13Eps Aquila
# Sulafat
# 52Ups Draco
# Zet Corona Australis
# 15Lam Lyra
# 12 Aquila
# 38Zet Sagittarius
# 14 Aquila
# Rho Telescopium
# 16 Lyra
# 39Omi Sagittarius
# 49 Draco
# 15 Aquila
# Gam Corona Australis
# Sig Octans
# 40Tau Sagittarius
# 16Lam Aquila
# Delphinus Corona Australis
# 18 Aquila
# 51 Draco
# Alp Corona Australis
# Bet Corona Australis
# 17 Lyra
# 18Iot Lyra
# 41Pi Sagittarius
# 19 Aquila
# Taurus Pavo
# 20 Aquila
# 19 Lyra
# 21 Aquila
# 55 Draco
# 42Psi Sagittarius
# 53 Draco
# Aladfar
# 1 Sagitta
# 22 Aquila
# 43 Sagittarius
# 1 Vulpecula
# 54 Draco
# 59 Draco
# 21The Lyra
# 2 Vulpecula
# 23 Aquila
# 24 Aquila
# 1Kap Cygnus
# Eta Telescopium
# 28 Aquila
# 26 Aquila
# 27 Aquila
# 46Ups Sagittarius
# Alp Sagittarius
# 60Tau Draco
# 3 Vulpecula
# 2 Sagitta
# 58Pi Draco
# 2 Cygnus
# 31 Aquila
# 50 Sagittarius
# 30Del Aquila
# 4 Vulpecula
# 32Nu Aquila
# 5 Vulpecula
# Mu Telescopium
# Lam Ursa Minor
# 4 Cygnus
# 35 Aquila
# Anser
# 8 Vulpecula
# 7 Vulpecula
# 36 Aquila
# Albireo
# Iot Telescopium
# 8 Cygnus
# 38Mu Aquila
# 37 Aquila
# 51 Sagittarius
# 9 Vulpecula
# 52 Sagittarius
# 9 Cygnus
# 39Kap Aquila
# 41Iot Aquila
# 11 Cygnus
# 42 Aquila
# 4Eps Sagitta
# 13The Cygnus
# 53 Sagittarius
# 44Sig Aquila
# 54 Sagittarius
# 12Phi Cygnus
# Sham
# 45 Aquila
# 14 Cygnus
# 6Bet Sagitta
# 55 Sagittarius
# 46 Aquila
# 47Chi Aquila
# 16 Cygnus
# 10 Vulpecula
# Nu Telescopium
# 48Psi Aquila
# 56 Sagittarius
# 15 Cygnus
# 49Ups Aquila
# Tarazed
# 17 Cygnus
# 7Del Sagitta
# 52Pi Aquila
# 8Zet Sagitta
# 51 Aquila
# Altair
# 54Omi Aquila
# 57 Sagittarius
# Chi Cygnus
# 12 Vulpecula
# 19 Cygnus
# 55Eta Aquila
# 9 Sagitta
# 20 Cygnus
# Iot Sagittarius
# 63Eps Draco
# 56 Aquila
# Eps Pavo
# 13 Vulpecula
# 57 Aquila
# 57 Aquila
# Libertas
# 58 Aquila
# 58Ome Sagittarius
# Alshain
# Mu 1Pav
# 59 Sagittarius
# 23 Cygnus
# 10 Sagitta
# 61Phi Aquila
# Mu 2Pav
# 22 Cygnus
# 61 Sagittarius
# 21Eta Cygnus
# 60 Sagittarius
# 24Psi Cygnus
# 11 Sagitta
# 12Gam Sagitta
# 14 Vulpecula
# 13 Sagitta
# 25 Cygnus
# 63 Sagittarius
# 62 Sagittarius
# 15 Vulpecula
# 16 Vulpecula
# 26 Cygnus
# Delphinus Pavo
# 62 Aquila
# 63Tau Aquila
# 15 Sagitta
# Xi Telescopium
# 65 Sagittarius
# 64 Draco
# 16Eta Sagitta
# 65 Draco
# 67Rho Draco
# 69 Draco
# 17 Vulpecula
# 27 Cygnus
# 64 Aquila
# 66 Draco
# 17The Sagitta
# 28 Cygnus
# 65The Aquila
# 18 Vulpecula
# 19 Vulpecula
# 20 Vulpecula
# 66 Aquila
# 67Rho Aquila
# 68 Draco
# 30 Cygnus
# 21 Vulpecula
# 31 Cygnus
# 29 Cygnus
# 3 Capricornus
# 33 Cygnus
# 22 Vulpecula
# 23 Vulpecula
# 18 Sagitta
# 4 Capricornus
# 1Kap Cepheus
# 32 Cygnus
# 24 Vulpecula
# 7Sig Capricornus
# 34 Cygnus
# 36 Cygnus
# 35 Cygnus
# 8Nu Capricornus
# 9Bet Capricornus
# 25 Vulpecula
# Alp Pavo
# 71 Draco
# 39 Cygnus
# 10Pi Capricornus
# 68 Aquila
# 11Rho Capricornus
# 40 Cygnus
# 43 Cygnus
# 12Omi Capricornus
# 12Omi Capricornus
# 69 Aquila
# 41 Cygnus
# 42 Cygnus
# 1 Delphinus
# Nu Microscopium
# 44 Cygnus
# 2The Cepheus
# 3Eta Delphinus
# Rho Pavo
# Mu 1Oct
# Mu 2Oct
# 47 Cygnus
# Alp Indus
# 4Zet Delphinus
# 70 Aquila
# 26 Vulpecula
# 73 Draco
# 27 Vulpecula
# Ups Pavo
# 6Bet Delphinus
# 5Iot Delphinus
# 71 Aquila
# 48 Cygnus
# 14Tau Capricornus
# 29 Vulpecula
# 8The Delphinus
# 28 Vulpecula
# 7Kap Delphinus
# 1 Aquarius
# 15Ups Capricornus
# 75 Draco
# Sualocin
# 74 Draco
# Bet Pavo
# 10 Delphinus
# Eta Indus
# 49 Cygnus
# Deneb
# 11Del Delphinus
# 51 Cygnus
# Sig Pavo
# 16Psi Capricornus
# 17 Capricornus
# 30 Vulpecula
# 52 Cygnus
# Iot Microscopium
# 4 Cepheus
# 2Eps Aquarius
# 3 Aquarius
# Zet Indus
# 13 Delphinus
# 3Eta Cepheus
# 54Lam Cygnus
# Alp Microscopium
# Iot Indus
# 15 Delphinus
# 14 Delphinus
# 55 Cygnus
# Bet Microscopium
# 18Ome Capricornus
# 4 Aquarius
# 56 Cygnus
# 5 Aquarius
# Bet Indus
# 6Mu Aquarius
# 31 Vulpecula
# 19 Capricornus
# 57 Cygnus
# 76 Draco
# 32 Vulpecula
# 17 Delphinus
# 16 Delphinus
# 7 Aquarius
# Alp Octans
# 58Nu Cygnus
# Musica
# 33 Vulpecula
# 20 Capricornus
# 1Eps Equuleus
# Gam Microscopium
# 11 Aquarius
# 59 Cygnus
# Zet Microscopium
# 60 Cygnus
# Mu Indus
# 12 Aquarius
# 22Eta Capricornus
# 3 Equuleus
# Eta Microscopium
# Delphinus Microscopium
# 23The Capricornus
# 4 Equuleus
# 62Xi Cygnus
# 24 Capricornus
# 61 Cygnus
# 61 Cygnus
# 25Chi Capricornus
# 63 Cygnus
# 27 Capricornus
# Omi Pavo
# 13Nu Aquarius
# 5Gam Equuleus
# 6 Equuleus
# 64Zet Cygnus
# 7Del Equuleus
# 28Phi Capricornus
# 29 Capricornus
# 65Tau Cygnus
# Kitalpha
# Eps Microscopium
# 30 Capricornus
# 31 Capricornus
# The Indus
# 15 Aquarius
# 67Sig Cygnus
# 66Ups Cygnus
# 68 Cygnus
# 16 Aquarius
# Alderamin
# 9 Equuleus
# 32Iot Capricornus
# 6 Cepheus
# 1 Pegasus
# 17 Aquarius
# 10Bet Equuleus
# Gam Pavo
# 33 Capricornus
# 18 Aquarius
# Gam Indus
# 20 Aquarius
# 19 Aquarius
# 21 Aquarius
# 34Zet Capricornus
# 35 Capricornus
# 69 Cygnus
# 36 Capricornus
# 5 Piscis Austrinus
# 70 Cygnus
# 35 Vulpecula
# 2 Pegasus
# 7 Cepheus
# 71 Cygnus
# Xi Grus
# 6 Piscis Austrinus
# 22Bet Aquarius
# Alfirk
# 37 Capricornus
# 73Rho Cygnus
# 8 Piscis Austrinus
# Nu Octans
# 72 Cygnus
# 7 Piscis Austrinus
# 39Eps Capricornus
# 23Xi Aquarius
# 3 Pegasus
# 74 Cygnus
# 5 Pegasus
# 4 Pegasus
# 25 Aquarius
# 40Gam Capricornus
# 9 Cepheus
# Lam Octans
# 42 Capricornus
# 75 Cygnus
# 41 Capricornus
# 26 Aquarius
# 43Kap Capricornus
# 7 Pegasus
# 76 Cygnus
# 44 Capricornus
# 77 Cygnus
# Azelfafage
# 45 Capricornus
# 9Iot Piscis Austrinus
# 79 Cygnus
# Enif
# 46 Capricornus
# 9 Pegasus
# 10Kap Pegasus
# Mu Cepheus
# 11 Cepheus
# 47 Capricornus
# 48Lam Capricornus
# 12 Pegasus
# 49Del Capricornus
# 10The Piscis Austrinus
# 11 Pegasus
# Omi Indus
# 10Nu Cepheus
# 12 Cepheus
# 14 Pegasus
# 13 Pegasus
# 51Mu Capricornus
# Gam Grus
# 15 Pegasus
# 16 Pegasus
# Pi Indus
# Delphinus Indus
# 13 Cepheus
# 17 Pegasus
# 18 Pegasus
# 12Eta Piscis Austrinus
# Eps Indus
# 28 Aquarius
# 20 Pegasus
# 19 Pegasus
# 29 Aquarius
# 16 Cepheus
# 30 Aquarius
# 31Omi Aquarius
# 21 Pegasus
# 13 Piscis Austrinus
# 14 Cepheus
# 32 Aquarius
# Lam Grus
# 22Nu Pegasus
# 34Alp Aquarius
# 18 Cepheus
# 33Iot Aquarius
# 23 Pegasus
# Alp Grus
# 20 Cepheus
# 19 Cepheus
# 24Iot Pegasus
# 14Mu Piscis Austrinus
# Ups Piscis Austrinus
# 25 Pegasus
# 35 Aquarius
# 15Tau Piscis Austrinus
# Biham
# 38 Aquarius
# 28 Pegasus
# 39 Aquarius
# 21Zet Cepheus
# 24 Cepheus
# 22Lam Cepheus
# Psi Octans
# 16Lam Piscis Austrinus
# 41 Aquarius
# Eps Octans
# Mu 1Gru
# Mu 2Gru
# 23Eps Cepheus
# 42 Aquarius
# 1 Lacerta
# 43The Aquarius
# Alp Tucana
# 44 Aquarius
# Ups Octans
# 45 Aquarius
# 25 Cepheus
# 46Rho Aquarius
# 30 Pegasus
# Nu Indus
# 47 Aquarius
# 48Gam Aquarius
# 31 Pegasus
# Pi 1Gru
# 32 Pegasus
# 2 Lacerta
# Pi 2Gru
# 49 Aquarius
# 33 Pegasus
# 51 Aquarius
# 50 Aquarius
# 3Bet Lacerta
# 52Pi Aquarius
# Delphinus Tucana
# 4 Lacerta
# 53 Aquarius
# 53 Aquarius
# 34 Pegasus
# 35 Pegasus
# Nu Grus
# 26 Cepheus
# 36 Pegasus
# 37 Pegasus
# 56 Aquarius
# Zet Piscis Austrinus
# 27Del Cepheus
# 5 Lacerta
# 57Sig Aquarius
# 38 Pegasus
# 17Bet Piscis Austrinus
# 6 Lacerta
# Nu Tucana
# 58 Aquarius
# 7Alp Lacerta
# 39 Pegasus
# 60 Aquarius
# 59Ups Aquarius
# 62Eta Aquarius
# 8 Lacerta
# 63Kap Aquarius
# 9 Lacerta
# 31 Cepheus
# 40 Pegasus
# 10 Lacerta
# 41 Pegasus
# 30 Cepheus
# 18Eps Piscis Austrinus
# Bet Octans
# 11 Lacerta
# Homam
# Bet Grus
# 19 Piscis Austrinus
# 12 Lacerta
# 43Omi Pegasus
# Rho Grus
# 67 Aquarius
# 66 Aquarius
# Matar
# Eta Grus
# 13 Lacerta
# 45 Pegasus
# Xi Octans
# 46Xi Pegasus
# 47Lam Pegasus
# 68 Aquarius
# Eps Grus
# 70 Aquarius
# 14 Lacerta
# 21 Piscis Austrinus
# 32Iot Cepheus
# 22Gam Piscis Austrinus
# 49Sig Pegasus
# 73Lam Aquarius
# 15 Lacerta
# Rho Indus
# 74 Aquarius
# 76Del Aquarius
# 78 Aquarius
# 77 Aquarius
# 1 Pisces
# 50Rho Pegasus
# 23Del Piscis Austrinus
# 16 Lacerta
# 24Alp Piscis Austrinus
# 52 Pegasus
# 2 Pisces
# Zet Grus
# 3 Pisces
# 81 Aquarius
# 1Omi Andromeda
# 82 Aquarius
# 2 And
# Pi Piscis Austrinus
# Kap Grus
# Scheat
# 3 Andromeda
# Markab
# 83 Aquarius
# The Grus
# 86 Aquarius
# Ups Grus
# 55 Pegasus
# 56 Pegasus
# 1 Cassiopeia
# 4 Andromeda
# 5 Andromeda
# 5 Pisces
# 88 Aquarius
# 57 Pegasus
# 89 Aquarius
# 33Pi Cepheus
# Iot Grus
# 58 Pegasus
# 2 Cassiopeia
# 6 Andromeda
# 59 Pegasus
# 60 Pegasus
# 7 Andromeda
# 90Phi Aquarius
# 61 Pegasus
# Gam Tucana
# 92Chi Aquarius
# 6Gam Pisces
# Phi Grus
# 8 Andromeda
# Taurus Octans
# Gam Sculptor
# 9 Andromeda
# 94 Aquarius
# 96 Aquarius
# 34Omi Cepheus
# 11 Andromeda
# 10 Andromeda
# 7 Pisces
# Salm
# 63 Pegasus
# 12 Andromeda
# 64 Pegasus
# 97 Aquarius
# 65 Pegasus
# 98 Aquarius
# 66 Pegasus
# 67 Pegasus
# 4 Cassiopeia
# 99 Aquarius
# Omi Grus
# 8Kap Pisces
# 9 Pisces
# 13 Andromeda
# 69 Pegasus
# 10The Pisces
# 70 Pegasus
# 100 Aquarius
# 13 Pisces
# Bet Sculptor
# 101 Aquarius
# 71 Pegasus
# 72 Pegasus
# 14 Pisces
# 15 Andromeda
# 73 Pegasus
# Iot Phoenix
# 16 Pisces
# 74 Pegasus
# 16Lam Andromeda
# 75 Pegasus
# 17Iot Andromeda
# The Phoenix
# 18 Andromeda
# 17Iot Pisces
# Mu Sculptor
# 19Kap Andromeda
# 103 Aquarius
# 104 Aquarius
# 18Lam Pisces
# 77 Pegasus
# 78 Pegasus
# 106 Aquarius
# 107 Aquarius
# 20Psi Andromeda
# 19 Pisces
# Sig Phoenix
# 5Tau Cassiopeia
# 20 Pisces
# Delphinus Sculptor
# 6 Cassiopeia
# 21 Pisces
# 79 Pegasus
# 80 Pegasus
# 108 Aquarius
# 22 Pisces
# 81Phi Pegasus
# 82 Pegasus
# 24 Pisces
# 25 Pisces
# 7Rho Cassiopeia
# 26 Pisces
# Eta Tucana
# 84Psi Pegasus
# 1 Cetus
# 27 Pisces
# Pi Phoenix
# 8Sig Cassiopeia
# 28Ome Pisces
# Eps Tucana
# Taurus Phoenix
# The Octans
# 29 Pisces
# 85 Pegasus
# 30 Pisces
# Zet Sculptor
# 31 Pisces
# 32 Pisces
# 2 Cetus
# 9 Cassiopeia
# 3 Cetus
# Acamar
# Achernar
# Acrab
# Acrux
# Adhara
# Ain
# Algedi
# Algorab
# Alkes
# Alnilam
# Alnitak
# Alphard
# Aludra
# Ancha
# Angetenar
# Antares
# Arkab Posterior
# Arkab Prior
# Arneb
# Ascella
# Aspidiske
# Atria
# Axolotl
# Azha
# Barnards Star
# Baten Kaitos
# Beid
# Brachium
# Buna
# Bunda
# Canopus
# Castor
# Ceibo
# Cervantes
# Chechia
# Cursa
# Dabih
# Deneb Algedi
# Dschubba
# Fang
# Felis
# Fomalhaut
# Franz
# Furud
# Gienah
# Hadar
# Illyrian
# Irena
# Kang
# Karaka
# Kaus Australis
# Kaus Borealis
# Kaus Media
# Keid
# Lerna
# Lesath
# Lich
# Lusitania
# Markeb
# Miaplacidus
# Mimosa
# Mintaka
# Mira
# Morava
# Moriah
# Muspelheim
# Naos
# Nashira
# Natasha
# Nihal
# Nunki
# Ogma
# Peacock
# Petra
# Phoenicia
# Polaris Australis
# Polis
# Porrima
# Proxima Centauri
# Ran
# Rigel
# Rotanev
# Rukbat
# Sabik
# Sadachbia
# Sadalmelik
# Sadalsuud
# Saiph
# Shama
# Shaula
# Sika
# Sirius
# Situla
# Skat
# Spica
# Suhail
# Syrma
# Terebellum
# Tupi
# Uruk
# Wezen
# Yed Posterior
# Yed Prior
# Zaniah
# Zaurak
# Zhang
